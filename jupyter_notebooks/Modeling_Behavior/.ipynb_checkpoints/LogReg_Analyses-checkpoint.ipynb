# %% [markdown]
# # Logistic Regression
#
# This logistic regression is based on the Beeler/Daw et al. 2010 paper.
# Specifically:
#
# dependent variable: binary choice of port (-1 or 1)
#
# explanatory variables:
# 1. the N previous rewards $ r_{t-N:t-1} $
# 2. the previous choice $c_{t-1}$ to capture a tendency to stay or switch
# 3. bias variable (1) to capture fixed, overall preference for either port
#
# Note: this model only carries information about ports when it gets a reward. IE -1 = right reward, 1 = left reward, but 0 = no reward (for either side). Should compare models with this information vs. added information about the non-rewarded port choices.

# %% [markdown]
# ## 02/19/2017
# I just ran the above code on the following data:
#
# - `full_9010_02192017.csv`
# - `full_8020_02192017.csv`
# - `full_7030_02192017.csv`
#
# Which were computed by compiling the following data:
# - block range: exactly 50 rewards
# - p(choose high Port) >= [p-0.1] where p = p(high Port)
#
# Observations:
# 1. F1 for each condition pretty similar. ~0.82-0.85
# 2. pseudo-R2 also similar: ~0.64-0.69
# 3. For (1) and (2) maybe a slight trend that 90-10 had a better model, but not certain.
# 4. For each condition, I tried adding in more ports (up to 3) into the past to see if it would help out. For all 3 conditions, decisions for t-N where 2 >= 2 had coefficients = 0. That is, the only non-zero beta for the ports was the most recent one.
#
# Next step:
#
#
# **Figures**
#
# 1. Logistic regression performs similarly across different conditions
#     - x axis: 90-10,80-20,70-30
#     - y axis: F1 score, pseudo-R2
# 2. Comparing model flexibility across different conditions
#     - x axis: number of previous rewards included (i.e. parameters in model)
#     - y axis: BIC
#     - color: each condition
# 3. Knowing where the non-rewarded trials are:
#     - what if you did the same regression, but instead you know where the non-rewarded trials are?
#     - also, compare to adding in previous ports (or rewards in the above scenario) and compare
#
# 4. Comparing 'strategies' across conditions
#     - train on 90-10, test on 80-20 (and all combinations)
#
# 5. Comparing 'strategies' across mice
#     - train on one mouse:condition pair, and test on another mouse:condition pair (for the same condition)

# %%
import sys
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sklearn.linear_model
import sklearn.tree
# %matplotlib inline

# %% [markdown]
# ## define function to do logistic regression and some basic evalutions

# %%
'''
I compiled the code above into a more compact function so I can cycle through different conditions/mice/etc 
as neccessary
'''

def logreg_and_eval(data,num_rewards=10,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    data_new = data.copy()
    for i in range(len(port_features)):
        data_new[reward_features[i]] = data[reward_features[i]].values*data[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    features.append('1_Port') #append the last decision as a feature
    features.append('Decision') #finally append the decision so we can take it to predict later
    
    #final version of data
    data = data_new[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            data_test_new[reward_features[i]] = test_data[reward_features[i]].values*test_data[port_features[i]].values
        
        data_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = data.iloc[:,:-1].values
        y_train = data.iloc[:,-1].values
        x_test = data_test.iloc[:,:-1].values
        y_test = data_test.iloc[:,-1].values
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = data.iloc[:,:-1].values
        y = data.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #calc true switches
    y_test_switch = np.abs(np.diff(y_test))
    #calc model switches
    y_predict_switch = np.abs(np.diff(y_predict))
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d,index=[0])
    features = features[:-1]
    features.append('Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %% [markdown]
# # Write here

# %%
data_90 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_9010_02192017.csv',index_col=0)
data_80 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_8020_02192017.csv',index_col=0)
data_70 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_7030_02192017.csv',index_col=0)

datas = [data_70,data_80,data_90]
models = []

# %%
for i,d in enumerate(datas):
    
    for j in range(30):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=7)
        models.append(models)

        if ((i == 0 and j == 0)):
            stats = stats_curr.copy()
            coefs = coefs_curr.copy()
        else:
            stats = stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

c = np.zeros(90)+70
c[30:] = 80
c[60:] = 90

stats.insert(0,'Condition',c)
coefs.insert(0,'Condition',c)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.241113
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2224.0          444.0
# True YES         418.0         2270.0
#
# F1: 0.840
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.241598
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2257.0          488.0
# True YES         432.0         2179.0
#
# F1: 0.826
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.239488
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2190.0          426.0
# True YES         478.0         2262.0
#
# F1: 0.833
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.242749
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2242.0          439.0
# True YES         415.0         2260.0
#
# F1: 0.841
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.238083
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2251.0          442.0
# True YES         458.0         2205.0
#
# F1: 0.831
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.241407
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2266.0          434.0
# True YES         406.0         2250.0
#
# F1: 0.843
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.236757
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2195.0          497.0
# True YES         447.0         2217.0
#
# F1: 0.824
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.236180
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2272.0          484.0
# True YES         424.0         2176.0
#
# F1: 0.827
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.239855
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2226.0          449.0
# True YES         453.0         2228.0
#
# F1: 0.832
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.233967
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2243.0          448.0
# True YES         467.0         2198.0
#
# F1: 0.828
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.241295
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2232.0          462.0
# True YES         452.0         2210.0
#
# F1: 0.829
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.236880
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2181.0          467.0
# True YES         440.0         2268.0
#
# F1: 0.833
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.238215
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2272.0          444.0
# True YES         462.0         2178.0
#
# F1: 0.828
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.238483
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2171.0          457.0
# True YES         465.0         2263.0
#
# F1: 0.831
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.240778
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2234.0          447.0
# True YES         427.0         2248.0
#
# F1: 0.837
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.243696
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2249.0          411.0
# True YES         425.0         2271.0
#
# F1: 0.845
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.237392
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2235.0          464.0
# True YES         456.0         2201.0
#
# F1: 0.827
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.235553
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2205.0          458.0
# True YES         442.0         2251.0
#
# F1: 0.833
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.239142
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2215.0          449.0
# True YES         456.0         2236.0
#
# F1: 0.832
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.235395
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2217.0          445.0
# True YES         475.0         2219.0
#
# F1: 0.828
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.237216
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2239.0          430.0
# True YES         481.0         2206.0
#
# F1: 0.829
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.241562
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2204.0          434.0
# True YES         447.0         2271.0
#
# F1: 0.838
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.240504
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2269.0          442.0
# True YES         438.0         2207.0
#
# F1: 0.834
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.236509
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2208.0          477.0
# True YES         443.0         2228.0
#
# F1: 0.829
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.239108
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2232.0          451.0
# True YES         451.0         2222.0
#
# F1: 0.831
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.237493
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2167.0          444.0
# True YES         458.0         2287.0
#
# F1: 0.835
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.244195
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2248.0          394.0
# True YES         444.0         2270.0
#
# F1: 0.844
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.239284
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2234.0          443.0
# True YES         465.0         2214.0
#
# F1: 0.830
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.237398
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2291.0          433.0
# True YES         453.0         2179.0
#
# F1: 0.831
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.235454
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2255.0          419.0
# True YES         505.0         2177.0
#
# F1: 0.825
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.249344
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6066.0         1339.0
# True YES        1261.0         5987.0
#
# F1: 0.822
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.247557
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6060.0         1291.0
# True YES        1353.0         5949.0
#
# F1: 0.818
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.247339
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5932.0         1362.0
# True YES        1300.0         6059.0
#
# F1: 0.820
#
# Accuracy on class 0: 0.81
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.251314
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6078.0         1238.0
# True YES        1292.0         6045.0
#
# F1: 0.827
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.243343
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5941.0         1364.0
# True YES        1344.0         6004.0
#
# F1: 0.816
#
# Accuracy on class 0: 0.81
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.246293
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6020.0         1277.0
# True YES        1343.0         6013.0
#
# F1: 0.821
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.247825
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5944.0         1315.0
# True YES        1303.0         6091.0
#
# F1: 0.823
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.246374
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6022.0         1340.0
# True YES        1340.0         5951.0
#
# F1: 0.816
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.248830
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6045.0         1279.0
# True YES        1257.0         6072.0
#
# F1: 0.827
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.244791
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6079.0         1360.0
# True YES        1330.0         5884.0
#
# F1: 0.814
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.247278
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5986.0         1295.0
# True YES        1353.0         6019.0
#
# F1: 0.820
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.249500
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6050.0         1250.0
# True YES        1304.0         6049.0
#
# F1: 0.826
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.244968
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6069.0         1331.0
# True YES        1353.0         5900.0
#
# F1: 0.815
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.244314
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6072.0         1390.0
# True YES        1332.0         5859.0
#
# F1: 0.811
#
# Accuracy on class 0: 0.81
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.248600
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6074.0         1291.0
# True YES        1343.0         5945.0
#
# F1: 0.819
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.251253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6148.0         1246.0
# True YES        1256.0         6003.0
#
# F1: 0.828
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.249009
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5970.0         1231.0
# True YES        1383.0         6069.0
#
# F1: 0.823
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.251172
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6156.0         1241.0
# True YES        1257.0         5999.0
#
# F1: 0.828
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.250569
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5991.0         1255.0
# True YES        1299.0         6108.0
#
# F1: 0.827
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.247756
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6129.0         1325.0
# True YES        1261.0         5938.0
#
# F1: 0.821
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.248569
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6076.0         1281.0
# True YES        1313.0         5983.0
#
# F1: 0.822
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.244711
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5984.0         1377.0
# True YES        1368.0         5924.0
#
# F1: 0.812
#
# Accuracy on class 0: 0.81
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.248645
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6023.0         1266.0
# True YES        1342.0         6022.0
#
# F1: 0.822
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.248312
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6099.0         1294.0
# True YES        1294.0         5966.0
#
# F1: 0.822
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.249164
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6065.0         1284.0
# True YES        1266.0         6038.0
#
# F1: 0.826
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.247809
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6147.0         1279.0
# True YES        1301.0         5926.0
#
# F1: 0.821
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.248637
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6032.0         1269.0
# True YES        1243.0         6109.0
#
# F1: 0.829
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.247592
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6044.0         1324.0
# True YES        1382.0         5903.0
#
# F1: 0.814
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.81
#
# Optimization terminated successfully.
#          Current function value: 0.249937
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6092.0         1251.0
# True YES        1319.0         5991.0
#
# F1: 0.823
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.247429
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6016.0         1328.0
# True YES        1302.0         6007.0
#
# F1: 0.820
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.218976
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1368.0          236.0
# True YES         248.0         1383.0
#
# F1: 0.851
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.220535
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1397.0          244.0
# True YES         230.0         1364.0
#
# F1: 0.852
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.86
#
# Optimization terminated successfully.
#          Current function value: 0.217245
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1370.0          259.0
# True YES         225.0         1381.0
#
# F1: 0.851
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.86
#
# Optimization terminated successfully.
#          Current function value: 0.221171
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1343.0          208.0
# True YES         245.0         1439.0
#
# F1: 0.864
#
# Accuracy on class 0: 0.87
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.213077
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1346.0          267.0
# True YES         264.0         1358.0
#
# F1: 0.836
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.218809
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1430.0          243.0
# True YES         219.0         1343.0
#
# F1: 0.853
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.86
#
# Optimization terminated successfully.
#          Current function value: 0.217277
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1358.0          242.0
# True YES         252.0         1383.0
#
# F1: 0.848
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.213854
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1390.0          248.0
# True YES         242.0         1355.0
#
# F1: 0.847
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.211621
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1333.0          270.0
# True YES         266.0         1366.0
#
# F1: 0.836
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.218265
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1363.0          250.0
# True YES         258.0         1364.0
#
# F1: 0.843
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.218531
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1421.0          244.0
# True YES         210.0         1360.0
#
# F1: 0.857
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.87
#
# Optimization terminated successfully.
#          Current function value: 0.218814
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1383.0          232.0
# True YES         240.0         1380.0
#
# F1: 0.854
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.218223
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1372.0          226.0
# True YES         248.0         1389.0
#
# F1: 0.854
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.219750
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1369.0          244.0
# True YES         258.0         1364.0
#
# F1: 0.845
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.218297
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1407.0          233.0
# True YES         251.0         1344.0
#
# F1: 0.847
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.214924
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1383.0          260.0
# True YES         218.0         1374.0
#
# F1: 0.852
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.86
#
# Optimization terminated successfully.
#          Current function value: 0.214731
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1327.0          239.0
# True YES         257.0         1412.0
#
# F1: 0.851
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.219721
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1377.0          237.0
# True YES         247.0         1374.0
#
# F1: 0.850
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.216524
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1399.0          226.0
# True YES         245.0         1365.0
#
# F1: 0.853
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.215015
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1344.0          249.0
# True YES         260.0         1382.0
#
# F1: 0.844
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.216618
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1371.0          263.0
# True YES         247.0         1354.0
#
# F1: 0.842
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.219292
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1401.0          227.0
# True YES         235.0         1372.0
#
# F1: 0.856
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.212034
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1380.0          248.0
# True YES         242.0         1365.0
#
# F1: 0.848
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.211703
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1322.0          254.0
# True YES         254.0         1405.0
#
# F1: 0.847
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.219742
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1412.0          264.0
# True YES         231.0         1328.0
#
# F1: 0.843
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.217016
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1366.0          237.0
# True YES         231.0         1401.0
#
# F1: 0.857
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.86
#
# Optimization terminated successfully.
#          Current function value: 0.206639
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1334.0          267.0
# True YES         261.0         1373.0
#
# F1: 0.839
#
# Accuracy on class 0: 0.83
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.218339
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1387.0          232.0
# True YES         240.0         1376.0
#
# F1: 0.854
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85
#
# Optimization terminated successfully.
#          Current function value: 0.217829
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1404.0          228.0
# True YES         252.0         1351.0
#
# F1: 0.849
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.221458
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1372.0          219.0
# True YES         253.0         1391.0
#
# F1: 0.855
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.85

# %% [markdown]
# # Comparing beta coefficients across conditions

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,4))
gs = gridspec.GridSpec(1,4,width_ratios=[2,1,1,1])

plt.subplot(gs[0])
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='red',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='green',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='navy',alpha=0.5)

plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
            color='red',label='90-10',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
            color='green',label='80-20',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
            color='navy',label='70-30',s=50)

plt.legend(loc='upper left')
plt.xticks(np.arange(coefs.shape[1]),coefs.columns.values,rotation='vertical')
plt.xlim(-0.5,8.5)
plt.title('Regression Coefficients')

plt.subplot(gs[1])
sns.barplot(x='Condition',y='Accuracy',data=stats)
plt.title('Accuracy (test)')
plt.ylim(0.7,1)

plt.subplot(gs[2])
sns.barplot(x='Condition',y='F1',data=stats)
plt.title('F1 (test)')
plt.ylim(0.7,1)

plt.subplot(gs[3])
sns.barplot(x='Condition',y='pseudo-R2',data=stats)
plt.title('pseudo-R2')
plt.ylim(0.5,0.8)

plt.tight_layout()

# %% [markdown]
# # Training / testing on different conditions

# %% [markdown]
# ### 1. Train on 90-10, test on 80-20 and 70-30

# %%
for i,d in enumerate([data_90,data_80,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_90,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_90 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.213974
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1399.0          246.0
# True YES         252.0         1338.0
#
# F1: 0.843
#
# Accuracy on class 0: 0.85
# Accuracy on class 1: 0.84
#
# Optimization terminated successfully.
#          Current function value: 0.216107
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        41098.0         2825.0
# True YES        4156.0          765.0
#
# F1: 0.180
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.216107
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        15081.0         1118.0
# True YES        1344.0          312.0
#
# F1: 0.202
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.19

# %%
stats_90['Testing Condition'] = [90,80,70]
stats_90
# Out:
#    Accuracy        F1  Testing Condition
# 0  0.915019  0.843100                 90
# 0  0.900993  0.179767                 80
# 0  0.907482  0.202203                 70

# %% [markdown]
# So this is interesting - accuracy stays pretty much the same across conditions, but F1 goes way down. And if we take a look at the confusion tables above, we can see it is because the accuracy on the switches went down (and accuracy on stays went up.

# %% [markdown]
# ### 2. Train on 80-20

# %%
for i,d in enumerate([data_80,data_90,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_80,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_80 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_80['Testing Condition'] = [80,90,70]
stats_80
# Out:
# Optimization terminated successfully.
#          Current function value: 0.246979
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5991.0         1310.0
# True YES        1334.0         6018.0
#
# F1: 0.820
#
# Accuracy on class 0: 0.82
# Accuracy on class 1: 0.82
#
# Optimization terminated successfully.
#          Current function value: 0.247334
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         9419.0          444.0
# True YES         794.0          128.0
#
# F1: 0.171
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.247334
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        15051.0         1148.0
# True YES        1332.0          324.0
#
# F1: 0.207
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.20
#    Accuracy        F1  Testing Condition
# 0  0.899891  0.819891                 80
# 0  0.918598  0.171352                 90
# 0  0.907706  0.207161                 70

# %% [markdown]
# ### 3. Train on 70-30

# %%
for i,d in enumerate([data_70,data_80,data_90]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_70,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_70 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_70['Testing Condition'] = [70,80,90]
stats_70
# Out:
# Optimization terminated successfully.
#          Current function value: 0.240564
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2214.0          436.0
# True YES         450.0         2256.0
#
# F1: 0.836
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.83
#
# Optimization terminated successfully.
#          Current function value: 0.238406
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        41013.0         2910.0
# True YES        4125.0          796.0
#
# F1: 0.185
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.238406
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         9407.0          456.0
# True YES         788.0          134.0
#
# F1: 0.177
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.15
#    Accuracy        F1  Testing Condition
# 0  0.911144  0.835865                 70
# 0  0.900727  0.184537                 80
# 0  0.917764  0.177249                 90

# %%
f1s = np.vstack((stats_90['F1'].values,
               stats_80['F1'].values[[1,0,2]],
               stats_70['F1'].values[[2,1,0]]))
sns.heatmap(f1s,vmin=0,vmax=1)
plt.xticks([0.5,1.5,2.5],['90','80','70'])
plt.yticks([0.5,1.5,2.5],['70','80','90'])
plt.ylabel('Testing Condition')
plt.xlabel('Training Condition')
plt.title('F1 scores when trained & tested on different conditions')

# %% [markdown]
# So if this is right, it means that the rules are different - what predicts a switch in 90-10 does not predict a switch in 80-20. But since most of the trials follow the last one, the accuracy doesn't drop very much. So it appears to be working fine, even though it is not.
#
# Can the difference be explained in the small differences in beta coefficient values? It must be ... what else is there? They seem similar enough that I'm surprised it makes such a difference.
#
# Let's go on to train and test on separate mice:

# %% [markdown]
# # Train/test on separate mice

# %% [markdown]
# First let's take a quick look at the mice's performances - specifically just at p(choose high P port):

# %%
data_90.insert(0,'Condition',0.9)
data_80.insert(0,'Condition',0.8)
data_70.insert(0,'Condition',0.7)

# %%
all_data = data_90.append(data_80)
all_data = all_data.append(data_70)
all_data.shape
# Out:
# (77487, 51)

# %%
sns.factorplot(x='Condition',y='Higher p port',hue='Mouse ID',data = all_data,legend=False,size=5,aspect=1.7)
plt.legend(bbox_to_anchor=(1.2,1))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylabel('rate higher prob port chosen',fontsize=20)
plt.title('Average p(choose better port) for each mouse across conditions',fontsize=20,x=0.5,y=1.1)

# %% [markdown]
# Okay, so based on this. Let's start with 80-20, and do a few different comparisons.
#
# 1. Start by training with harry, and testing on all the others.
# 2. Then try training on volde, testing on all others.
# 3. Finally train on someone in the middle - like Tom or q45, and test on others

# %%
mice = np.unique(data_80['Mouse ID'].values)

# %%
mice
# Out:
# array(['K1', 'dumble', 'harry', 'q40', 'q43', 'q45', 'quirrel', 'sprout',
#        'tom', 'tonks', 'volde'], dtype=object)

# %%
'''
Train on HARRY
'''
d_train = data_80[data_80['Mouse ID'] == 'harry'].copy()

for i,mouse in enumerate(mice):
    d_test = data_80[data_80['Mouse ID'] == mouse].copy()
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d_train,test_data = d_test)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(d_train,test_data = d_test)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats['Test Mouse'] = mice
stats
# Out:
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          307.0           31.0
# True YES          70.0           11.0
#
# F1: 0.179
#
# Accuracy on class 0: 0.91
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5650.0          350.0
# True YES         510.0           82.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         6057.0          257.0
# True YES         385.0           64.0
#
# F1: 0.166
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         1198.0           62.0
# True YES         122.0           13.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.10
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         6732.0          404.0
# True YES         571.0          102.0
#
# F1: 0.173
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.15
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          974.0          102.0
# True YES         155.0           26.0
#
# F1: 0.168
#
# Accuracy on class 0: 0.91
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4893.0          293.0
# True YES         398.0           53.0
#
# F1: 0.133
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.12
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4212.0          408.0
# True YES         752.0          117.0
#
# F1: 0.168
#
# Accuracy on class 0: 0.91
# Accuracy on class 1: 0.13
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3587.0          249.0
# True YES         356.0           75.0
#
# F1: 0.199
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4989.0          312.0
# True YES         511.0           63.0
#
# F1: 0.133
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.11
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2609.0          236.0
# True YES         405.0           81.0
#
# F1: 0.202
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.17
#    Accuracy        F1 Test Mouse
# 0  0.833333  0.178862         K1
# 0  0.911270  0.160156     dumble
# 0  0.937020  0.166234      harry
# 0  0.910458  0.123810        q40
# 0  0.911908  0.173028        q43
# 0  0.856916  0.168285        q45
# 0  0.915041  0.132999    quirrel
# 0  0.853188  0.167862     sprout
# 0  0.896204  0.198675        tom
# 0  0.904016  0.132771      tonks
# 0  0.856843  0.201743      volde

# %%
'''
TROUBLE SHOOTING
'''
data = data_80.copy()
test_data = data_80.copy()
num_rewards = 10


from statsmodels.discrete.discrete_model import Logit

port_features = []
reward_features = []

#change right port to -1 instead of 0
for col in data:
    if '_Port' in col:
        data.loc[data[col] == 0,col] = -1
        port_features.append(col)
    elif '_Reward' in col:
        reward_features.append(col)

#create new feature matrix
data_new = data.copy()
for i in range(len(port_features)):
    data_new[reward_features[i]] = data[reward_features[i]].values*data[port_features[i]].values


#determine the features
features = reward_features.copy()
features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
features.append('1_Port') #append the last decision as a feature
features.append('Decision') #finally append the decision so we can take it to predict later

#final version of data
data = data_new[features].copy() #this now just has the features we want and the decision we want to predict

#do the same thing for the test data if it exists!
if test_data is not False:
    print('take it all')
    for col in test_data:
        if '_Port' in col:
            test_data.loc[test_data[col] == 0,col] = -1

    #create new feature matrix
    data_test_new = test_data.copy()
    for i in range(len(port_features)):
        data_test_new[reward_features[i]] = test_data[reward_features[i]].values*test_data[port_features[i]].values

    data_test = data_test_new[features].copy()


    #set training and testing sets now
    x_train = data.iloc[:,:-1].values
    y_train = data.iloc[:,-1].values
    x_test = data_test.iloc[:,:-1].values
    y_test = data_test.iloc[:,-1].values

#if there is no test data, then split up the data into training and testing
elif test_data is False:
    print("everyday I'm shuffling")
    #extract features and decisions
    x = data.iloc[:,:-1].values
    y = data.iloc[:,-1].values

    #split into training and testing
    n_trials = x.shape[0]
    shuf_inds = np.random.permutation(n_trials)
    split_ind = int(n_trials*0.7)

    x_train = x[shuf_inds[:split_ind],:]
    y_train = y[shuf_inds[:split_ind]]

    x_test = x[shuf_inds[split_ind:],:]
    y_test = y[shuf_inds[split_ind:]]
else:
    print('Something effed up')
    
'''
Modeling
'''

#fit logistic regression
logreg = sklearn.linear_model.LogisticRegressionCV()
logreg.fit(x_train,y_train)

#predict on testing set
y_predict = logreg.predict(x_test)
y_predict_proba = logreg.predict_proba(x_test)

#model accuracy
score = logreg.score(x_test,y_test)

#calculating pseudo-R2 and BIC from statsmodel OLS
model = Logit(y_train,x_train)
rslt  = model.fit()

#calc true switches
y_test_switch = np.abs(np.diff(y_test))
#calc model switches
y_predict_switch = np.abs(np.diff(y_predict))
acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)

#extract coefficients
coefs = logreg.coef_ #retrieve coefs
coefs = np.append(coefs[0],logreg.intercept_) #add bias coef

#create stats database to return
d = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
stats = pd.DataFrame(data=d,index=[0])
features = features[:-1]
features.append('Bias')

coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
# Out:
# take it all
# Optimization terminated successfully.
#          Current function value: 0.247334
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        40992.0         2931.0
# True YES        4126.0          795.0
#
# F1: 0.184
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.16

# %%
y_pred = logreg.predict(x_test)
s_pred = np.abs(np.diff(y_pred))

# %%
sf.score_both_and_confuse(s_pred,s_true,confusion=False,disp=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-631b02969b87> in <module>()
# ----> 1 sf.score_both_and_confuse(s_pred,s_true,confusion=False,disp=True)
#
# NameError: name 's_true' is not defined

# %%
x_train.shape

# %%
np.sum(y_test - y_train)

# %%
y_train.sum()
