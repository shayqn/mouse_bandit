# %% [markdown]
# # Logistic Regression
#
# This logistic regression is based on the Beeler/Daw et al. 2010 paper.
# Specifically:
#
# dependent variable: binary choice of port (-1 or 1)
#
# explanatory variables:
# 1. the N previous rewards $ r_{t-N:t-1} $
# 2. the previous choice $c_{t-1}$ to capture a tendency to stay or switch
# 3. bias variable (1) to capture fixed, overall preference for either port
#
# Note: this model only carries information about ports when it gets a reward. IE -1 = right reward, 1 = left reward, but 0 = no reward (for either side). Should compare models with this information vs. added information about the non-rewarded port choices.

# %% [markdown]
# ## 02/19/2017
# I just ran the above code on the following data:
#
# - `full_9010_02192017.csv`
# - `full_8020_02192017.csv`
# - `full_7030_02192017.csv`
#
# Which were computed by compiling the following data:
# - block range: exactly 50 rewards
# - p(choose high Port) >= [p-0.1] where p = p(high Port)
#
# Observations:
# 1. pseudo-R2 also similar: ~0.64-0.69
# 2. For (1)  maybe a slight trend that 90-10 had a better model, but not certain.
# 3. For each condition, I tried adding in more ports (up to 3) into the past to see if it would help out. For all 3 conditions, decisions for t-N where 2 >= 2 had coefficients = 0. That is, the only non-zero beta for the ports was the most recent one.
#
# Next step:
#
#
# **Figures**
#
# 1. Logistic regression performs similarly across different conditions
#     - x axis: 90-10,80-20,70-30
#     - y axis: F1 score, pseudo-R2
# 2. Comparing model flexibility across different conditions
#     - x axis: number of previous rewards included (i.e. parameters in model)
#     - y axis: BIC
#     - color: each condition
# 3. Knowing where the non-rewarded trials are:
#     - what if you did the same regression, but instead you know where the non-rewarded trials are?
#     - also, compare to adding in previous ports (or rewards in the above scenario) and compare
#
# 4. Comparing 'strategies' across conditions
#     - train on 90-10, test on 80-20 (and all combinations)
#
# 5. Comparing 'strategies' across mice
#     - train on one mouse:condition pair, and test on another mouse:condition pair (for the same condition)

# %%
import sys
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sklearn.linear_model
import sklearn.tree
# %matplotlib inline

# %% [markdown]
# ## define function to do logistic regression and some basic evalutions

# %%
'''
I compiled the code above into a more compact function so I can cycle through different conditions/mice/etc 
as neccessary
'''

def logreg_and_eval(data,num_rewards=10,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix and INVERT THE REWARDS
    #so here -1 --> NO REWARD on the right side
    # and 1--> NO REWARD on the left side
    # and 0 --> Reward on either side
    d = data.copy()
    for i in range(len(port_features)):
        inv_rewards = np.abs(d[reward_features[i]].values - 1)
        d[reward_features[i]] = inv_rewards*d[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    features.append('1_Port') #append the last decision as a feature
    features.append('Decision') #finally append the decision so we can take it to predict later
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            inv_rewards = np.abs(data_test_new[reward_features[i]].values - 1)
            data_test_new[reward_features[i]] = inv_rewards*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = d_test['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = d['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features.append('Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %%
def logreg_and_eval_withports(data,num_rewards=10,num_ports=1,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    d = data.copy()
    for i in range(len(port_features)):
        inv_rewards = np.abs(d[reward_features[i]].values - 1)
        d[reward_features[i]] = inv_rewards*d[port_features[i]].values
    
    #determine the features
    features = reward_features.copy()
    if num_rewards == 0:
        features = port_features[-1*num_ports:]
    elif num_ports == 0:
        features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    else:
        features = features[-1*num_rewards:]
        features = np.append(features,port_features[-1*num_ports:])
    
    print(features)
    features = np.append(features,'Decision') #finally append the decision so we can take it to predict later
    
    
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            inv_rewards = np.abs(data_test_new[reward_features[i]].values - 1)
            data_test_new[reward_features[i]] = inv_rewards*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = test_data['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = data['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'F1':F1,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features = np.append(features,'Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %% [markdown]
# # Write here

# %%
data_90 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_9010_02192017.csv',index_col=0)
data_80 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_8020_02192017.csv',index_col=0)
data_70 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_7030_02192017.csv',index_col=0)

datas = [data_70,data_80,data_90]
models = []

# %%
for i,d in enumerate(datas):
    
    for j in range(30):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=7)
        models.append(models)

        if ((i == 0 and j == 0)):
            stats = stats_curr.copy()
            coefs = coefs_curr.copy()
        else:
            stats = stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

c = np.zeros(90)+70
c[30:] = 80
c[60:] = 90

stats.insert(0,'Condition',c)
coefs.insert(0,'Condition',c)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.254860
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4851.0            0.0
# True YES         506.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256197
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4855.0            0.0
# True YES         502.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.258711
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4873.0            0.0
# True YES         484.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.257015
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4854.0            0.0
# True YES         503.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.254106
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4854.0            0.0
# True YES         503.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259037
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4883.0            0.0
# True YES         474.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.251966
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4849.0            0.0
# True YES         508.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.257503
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4849.0            0.0
# True YES         508.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260318
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4877.0            0.0
# True YES         480.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.258535
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4862.0            0.0
# True YES         495.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256248
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4858.0            0.0
# True YES         499.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264470
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4906.0            0.0
# True YES         451.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256258
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4855.0            0.0
# True YES         502.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256975
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4869.0            0.0
# True YES         488.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260524
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4876.0            0.0
# True YES         481.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261219
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4901.0            0.0
# True YES         456.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.254769
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4838.0            0.0
# True YES         519.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.253852
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4840.0            0.0
# True YES         517.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.254321
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4847.0            0.0
# True YES         510.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259563
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4855.0            0.0
# True YES         502.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256491
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4870.0            0.0
# True YES         487.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.257734
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4864.0            0.0
# True YES         493.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259397
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4879.0            0.0
# True YES         478.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.258017
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4876.0            0.0
# True YES         481.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.253696
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4831.0            0.0
# True YES         526.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.253423
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4836.0            0.0
# True YES         521.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259661
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4882.0            0.0
# True YES         475.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.255820
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4857.0            0.0
# True YES         500.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261776
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4905.0            0.0
# True YES         452.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259961
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4888.0            0.0
# True YES         469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264687
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13171.0            0.0
# True YES        1483.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266321
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13229.0            0.0
# True YES        1425.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263620
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13183.0            0.0
# True YES        1471.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264169
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13201.0            0.0
# True YES        1453.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263646
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13178.0            0.0
# True YES        1476.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263560
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13165.0            0.0
# True YES        1489.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261663
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13173.0            0.0
# True YES        1481.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265785
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13215.0            0.0
# True YES        1439.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265009
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261872
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13169.0            0.0
# True YES        1485.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264715
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13218.0            0.0
# True YES        1436.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265056
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13224.0            0.0
# True YES        1430.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262517
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13158.0            0.0
# True YES        1496.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260234
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13127.0            0.0
# True YES        1527.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264196
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13220.0            0.0
# True YES        1434.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265039
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13186.0            0.0
# True YES        1468.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264994
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13204.0            0.0
# True YES        1450.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264733
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13235.0            0.0
# True YES        1419.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265308
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266301
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13240.0            0.0
# True YES        1414.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261399
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13179.0            0.0
# True YES        1475.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264381
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13221.0            0.0
# True YES        1433.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261889
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13191.0            0.0
# True YES        1463.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262344
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13152.0            0.0
# True YES        1502.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263443
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13211.0            0.0
# True YES        1443.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263558
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263093
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13160.0            0.0
# True YES        1494.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266468
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13229.0            0.0
# True YES        1425.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264231
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265140
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13224.0            0.0
# True YES        1430.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.226302
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2945.0            0.0
# True YES         291.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232203
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2953.0            0.0
# True YES         283.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.230874
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2966.0            0.0
# True YES         270.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232864
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2965.0            0.0
# True YES         271.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232197
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2955.0            0.0
# True YES         281.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.233897
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2969.0            0.0
# True YES         267.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.237116
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2983.0            0.0
# True YES         253.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.226000
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2938.0            0.0
# True YES         298.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.233793
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2965.0            0.0
# True YES         271.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.229358
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2946.0            0.0
# True YES         290.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232993
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2976.0            0.0
# True YES         260.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.231920
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2966.0            0.0
# True YES         270.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.233381
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2960.0            0.0
# True YES         276.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.228908
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2966.0            0.0
# True YES         270.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.237529
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2978.0            0.0
# True YES         258.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.235055
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2970.0            0.0
# True YES         266.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.236523
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2967.0            0.0
# True YES         269.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.230038
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2966.0            0.0
# True YES         270.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.230579
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2947.0            0.0
# True YES         289.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.229011
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2946.0            0.0
# True YES         290.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232236
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2965.0            0.0
# True YES         271.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.235673
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2977.0            0.0
# True YES         259.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.234494
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2972.0            0.0
# True YES         264.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.231770
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2961.0            0.0
# True YES         275.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.231001
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2964.0            0.0
# True YES         272.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.228812
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2963.0            0.0
# True YES         273.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.229324
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2953.0            0.0
# True YES         283.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.233652
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2981.0            0.0
# True YES         255.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.239754
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2999.0            0.0
# True YES         237.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.233169
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2959.0            0.0
# True YES         277.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00

# %% [markdown]
# # Comparing beta coefficients across conditions

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,4))
gs = gridspec.GridSpec(1,4,width_ratios=[2,1,1,1])

plt.subplot(gs[0])
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='red',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='green',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='navy',alpha=0.5)

plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
            color='red',label='90-10',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
            color='green',label='80-20',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
            color='navy',label='70-30',s=50)

plt.legend(loc='upper left')
plt.xticks(np.arange(coefs.shape[1]),coefs.columns.values[1:],rotation='vertical')
plt.xlim(-0.5,8.5)
plt.title('Regression Coefficients')

plt.subplot(gs[1])
sns.barplot(x='Condition',y='Accuracy',data=stats)
plt.title('Accuracy (test)')
plt.ylim(0.7,1)

plt.subplot(gs[2])
sns.barplot(x='Condition',y='F1',data=stats)
plt.title('F1 (test)')
#plt.ylim(0.7,1)

plt.subplot(gs[3])
sns.barplot(x='Condition',y='pseudo-R2',data=stats)
plt.title('pseudo-R2')
plt.ylim(0,0.8)

plt.tight_layout()

# %% [markdown]
# ## Test number of parameters / model flexibility vs BIC

# %%
stats.head(2)
# Out:
#    Condition  Accuracy          BIC  F1  negative loglikelihood  pseudo-R2
# 0       70.0  0.906664  6430.088416   0             3177.310592   0.633178
# 0       70.0  0.910211  6563.525299   0             3244.029034   0.625534

# %%
d = data_80.copy()
stats = pd.DataFrame(columns=['Accuracy','BIC','negative loglikelihood','pseudo-R2','No. parameters'])

for i,n in enumerate(np.arange(10,0,-1)):
    
    for j in enumerate(range(30)):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=n)
        models.append(models)
        stats_curr['No. parameters'] = n
        stats = stats.append(stats_curr)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.264345
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13190.0            0.0
# True YES        1464.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263772
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262134
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13153.0            0.0
# True YES        1501.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263525
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263440
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13173.0            0.0
# True YES        1481.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263668
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13207.0            0.0
# True YES        1447.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265408
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13210.0            0.0
# True YES        1444.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264198
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13214.0            0.0
# True YES        1440.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264756
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13221.0            0.0
# True YES        1433.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264587
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13232.0            0.0
# True YES        1422.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265133
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13223.0            0.0
# True YES        1431.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265854
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13228.0            0.0
# True YES        1426.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261270
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264174
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13200.0            0.0
# True YES        1454.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262771
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264135
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260860
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13126.0            0.0
# True YES        1528.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261432
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13156.0            0.0
# True YES        1498.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262806
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13189.0            0.0
# True YES        1465.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265208
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13204.0            0.0
# True YES        1450.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263693
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13182.0            0.0
# True YES        1472.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261240
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13156.0            0.0
# True YES        1498.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264496
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13210.0            0.0
# True YES        1444.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264097
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13162.0            0.0
# True YES        1492.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266280
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13216.0            0.0
# True YES        1438.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262080
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13140.0            0.0
# True YES        1514.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262670
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13179.0            0.0
# True YES        1475.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261028
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13162.0            0.0
# True YES        1492.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260145
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13134.0            0.0
# True YES        1520.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263379
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13193.0            0.0
# True YES        1461.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262280
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261192
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13145.0            0.0
# True YES        1509.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.259883
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13125.0            0.0
# True YES        1529.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263300
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13182.0            0.0
# True YES        1472.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263115
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13188.0            0.0
# True YES        1466.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265825
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13247.0            0.0
# True YES        1407.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262501
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13197.0            0.0
# True YES        1457.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265154
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13203.0            0.0
# True YES        1451.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262721
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13167.0            0.0
# True YES        1487.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264392
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13168.0            0.0
# True YES        1486.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264323
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13202.0            0.0
# True YES        1452.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265390
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13200.0            0.0
# True YES        1454.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263234
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13182.0            0.0
# True YES        1472.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264064
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13176.0            0.0
# True YES        1478.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263367
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13212.0            0.0
# True YES        1442.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263258
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13167.0            0.0
# True YES        1487.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262427
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13168.0            0.0
# True YES        1486.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265428
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13226.0            0.0
# True YES        1428.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263990
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13216.0            0.0
# True YES        1438.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264133
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13206.0            0.0
# True YES        1448.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263537
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13177.0            0.0
# True YES        1477.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263845
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13230.0            0.0
# True YES        1424.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13175.0            0.0
# True YES        1479.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266330
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13228.0            0.0
# True YES        1426.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.267242
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13252.0            0.0
# True YES        1402.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262824
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13188.0            0.0
# True YES        1466.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261390
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13137.0            0.0
# True YES        1517.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261676
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13140.0            0.0
# True YES        1514.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263009
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13174.0            0.0
# True YES        1480.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265803
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13212.0            0.0
# True YES        1442.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264976
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13178.0            0.0
# True YES        1476.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264669
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13169.0            0.0
# True YES        1485.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264410
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13195.0            0.0
# True YES        1459.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264715
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13172.0            0.0
# True YES        1482.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262380
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13184.0            0.0
# True YES        1470.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264944
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13208.0            0.0
# True YES        1446.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263062
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261262
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13154.0            0.0
# True YES        1500.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260700
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13148.0            0.0
# True YES        1506.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265487
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13197.0            0.0
# True YES        1457.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266262
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13216.0            0.0
# True YES        1438.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263672
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13158.0            0.0
# True YES        1496.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13175.0            0.0
# True YES        1479.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260461
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13105.0            0.0
# True YES        1549.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266807
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13243.0            0.0
# True YES        1411.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264272
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264538
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13164.0            0.0
# True YES        1490.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263022
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263659
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13173.0            0.0
# True YES        1481.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260780
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13137.0            0.0
# True YES        1517.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264787
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13189.0            0.0
# True YES        1465.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262710
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13170.0            0.0
# True YES        1484.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264656
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13220.0            0.0
# True YES        1434.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265427
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13218.0            0.0
# True YES        1436.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264776
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13187.0            0.0
# True YES        1467.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263453
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13201.0            0.0
# True YES        1453.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265355
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13213.0            0.0
# True YES        1441.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263114
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13175.0            0.0
# True YES        1479.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264520
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13209.0            0.0
# True YES        1445.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00

# %%
plt.figure(figsize=(10,4))
sns.factorplot(x='No. parameters',y='BIC',data=stats,color='black')
plt.title('BIC vs model flexibility')

# %%
BIC = np.zeros((10,10))
F1 = np.zeros((10,10))
R2 = np.zeros((10,10))
acc = np.zeros((10,10))

for i in range(10):
    for j in range(10):
        if not ((j==0) & (i==0)):
            model_curr,stats_curr,coefs_curr = logreg_and_eval_withports(d,num_rewards=i,num_ports=j)
            BIC[i,j] = stats_curr['BIC'].values
            F1[i,j] = stats_curr['F1'].values
            R2[i,j] = stats_curr['pseudo-R2'].values
            acc[i,j] = stats_curr['Accuracy'].values
# Out:
# ['1_Port']
# Optimization terminated successfully.
#          Current function value: 0.325269
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13192.0            0.0
# True YES        1462.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.314696
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13191.0            0.0
# True YES        1463.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.314113
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13245.0            0.0
# True YES        1409.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.311382
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13228.0            0.0
# True YES        1426.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.307057
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13169.0            0.0
# True YES        1485.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.304201
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13141.0            0.0
# True YES        1513.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.304433
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13162.0            0.0
# True YES        1492.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.305526
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['9_Port', '8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.307800
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13221.0            0.0
# True YES        1433.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.656037
#          Iterations 5
#           Predicted NO  Predicted YES
# True NO         8527.0         4745.0
# True YES        1261.0          121.0
#
# F1: 0.039
#
# Accuracy on class 0: 0.64
# Accuracy on class 1: 0.09
#
# ['1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246244
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12992.0          143.0
# True YES        1366.0          153.0
#
# F1: 0.169
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247666
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13068.0          122.0
# True YES        1319.0          145.0
#
# F1: 0.168
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246472
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13052.0          144.0
# True YES        1292.0          166.0
#
# F1: 0.188
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246966
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13005.0          166.0
# True YES        1310.0          173.0
#
# F1: 0.190
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248882
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13062.0          155.0
# True YES        1278.0          159.0
#
# F1: 0.182
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward', '8_Reward', '7_Reward', '6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.639449
#          Iterations 5
#           Predicted NO  Predicted YES
# True NO         9913.0         3248.0
# True YES        1369.0          124.0
#
# F1: 0.051
#
# Accuracy on class 0: 0.75
# Accuracy on class 1: 0.08
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.264446
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13184.0            0.0
# True YES        1470.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247210
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13058.0          102.0
# True YES        1378.0          116.0
#
# F1: 0.136
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248497
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13068.0           97.0
# True YES        1373.0          116.0
#
# F1: 0.136
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246479
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13036.0          123.0
# True YES        1358.0          137.0
#
# F1: 0.156
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246998
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13039.0          147.0
# True YES        1329.0          139.0
#
# F1: 0.158
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.251033
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13127.0          158.0
# True YES        1232.0          137.0
#
# F1: 0.165
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245781
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13005.0          168.0
# True YES        1323.0          158.0
#
# F1: 0.175
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245939
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12982.0          150.0
# True YES        1339.0          183.0
#
# F1: 0.197
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248715
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13042.0          170.0
# True YES        1271.0          171.0
#
# F1: 0.192
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12

# %%
plt.figure(figsize=(20,5))
plt.suptitle('Model behavior vs # of rewards and decisions included',x=0.5,y=1.05,fontsize=20)

plt.subplot(141)
sns.heatmap(BIC,vmin=15000,vmax=25000)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('BIC',fontsize=15)

plt.subplot(142)
sns.heatmap(F1)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('F1',fontsize=15)

plt.subplot(143)
sns.heatmap(R2,vmin=0.5)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('R2')

plt.subplot(144)
sns.heatmap(acc,vmin=0.8)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('Accuracy')

plt.tight_layout()

# %% [markdown]
# # Training / testing on different conditions

# %% [markdown]
# ### 1. Train on 90-10, test on 80-20 and 70-30

# %%
for i,d in enumerate([data_90,data_80,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_90,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_90 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.231716
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2969.0            0.0
# True YES         267.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.232174
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO        23217.0        20744.0
# True YES        2496.0         2388.0
#
# F1: 0.170
#
# Accuracy on class 0: 0.53
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.232174
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         8226.0         7987.0
# True YES         842.0          801.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49

# %%
stats_90['Testing Condition'] = [90,80,70]
stats_90
# Out:
#    Accuracy        F1  Testing Condition
# 0  0.917491  0.000000                 90
# 0  0.524209  0.170474                 80
# 0  0.505544  0.153581                 70

# %% [markdown]
# So this is interesting - accuracy stays pretty much the same across conditions, but F1 goes way down. And if we take a look at the confusion tables above, we can see it is because the accuracy on the switches went down (and accuracy on stays went up.

# %% [markdown]
# ### 2. Train on 80-20

# %%
for i,d in enumerate([data_80,data_90,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_80,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_80 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_80['Testing Condition'] = [80,90,70]
stats_80
# Out:
# Optimization terminated successfully.
#          Current function value: 0.260729
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13145.0            0.0
# True YES        1509.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263445
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5952.0         3923.0
# True YES         624.0          287.0
#
# F1: 0.112
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.263445
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12138.0         4075.0
# True YES        1240.0          403.0
#
# F1: 0.132
#
# Accuracy on class 0: 0.75
# Accuracy on class 1: 0.25
#    Accuracy        F1  Testing Condition
# 0  0.897025  0.000000                 80
# 0  0.578435  0.112087                 90
# 0  0.702341  0.131678                 70

# %% [markdown]
# ### 3. Train on 70-30

# %%
for i,d in enumerate([data_70,data_80,data_90]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_70,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_70 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_70['Testing Condition'] = [70,80,90]
stats_70
# Out:
# Optimization terminated successfully.
#          Current function value: 0.255697
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4866.0            0.0
# True YES         491.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.256850
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        37114.0         6847.0
# True YES        3739.0         1145.0
#
# F1: 0.178
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.256850
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         8343.0         1532.0
# True YES         699.0          212.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.23
#    Accuracy        F1  Testing Condition
# 0  0.908344  0.000000                 70
# 0  0.783274  0.177850                 80
# 0  0.793158  0.159699                 90

# %%
f1s = np.vstack((stats_90['F1'].values,
               stats_80['F1'].values[[1,0,2]],
               stats_70['F1'].values[[2,1,0]]))
sns.heatmap(f1s)
plt.xticks([0.5,1.5,2.5],['90','80','70'])
plt.yticks([0.5,1.5,2.5],['70','80','90'])
plt.ylabel('Testing Condition')
plt.xlabel('Training Condition')
plt.title('F1 scores when trained & tested on different conditions')

# %% [markdown]
# So if this is right, it means that the rules are different - what predicts a switch in 90-10 does not predict a switch in 80-20. But since most of the trials follow the last one, the accuracy doesn't drop very much. So it appears to be working fine, even though it is not.
#
# Can the difference be explained in the small differences in beta coefficient values? It must be ... what else is there? They seem similar enough that I'm surprised it makes such a difference.
#
# Let's go on to train and test on separate mice:

# %% [markdown]
# # Train/test on separate mice

# %% [markdown]
# First let's take a quick look at the mice's performances - specifically just at p(choose high P port):

# %%
data_90.insert(0,'Condition',0.9)
data_80.insert(0,'Condition',0.8)
data_70.insert(0,'Condition',0.7)

# %%
all_data = data_90.append(data_80)
all_data = all_data.append(data_70)
all_data.shape
# Out:
# (77487, 51)

# %%
sns.factorplot(x='Condition',y='Higher p port',hue='Mouse ID',data = all_data,legend=False,size=5,aspect=1.7)
plt.legend(bbox_to_anchor=(1.2,1))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylabel('rate higher prob port chosen',fontsize=20)
plt.title('Average p(choose better port) for each mouse across conditions',fontsize=20,x=0.5,y=1.1)

# %% [markdown]
# Okay, so based on this. Let's start with 80-20, and do a few different comparisons.
#
# 1. Start by training with harry, and testing on all the others.
# 2. Then try training on volde, testing on all others.
# 3. Finally train on someone in the middle - like Tom or q45, and test on others

# %%
'''
Loop through mice
'''
mice = np.unique(data_80['Mouse ID'].values)

stats = pd.DataFrame(columns=['Accuracy','F1','Training Mouse','Testing Mouse'])
test_mice = []
train_mice = []

for mouse_train in mice:

    d_train = data_80[data_80['Mouse ID'] == mouse_train].copy()

    for i,mouse_test in enumerate(mice):
        d_test = data_80[data_80['Mouse ID'] == mouse_test].copy()

        if i == 0:
            model,stats_curr,coefs = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats = stats.append(stats_curr)
        else:
            model,stats_curr,coefs_curr = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats= stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

        test_mice.append(mouse_test)
        train_mice.append(mouse_train)

stats['Testing Mouse'] = test_mice
stats['Training Mouse'] = train_mice
acc_matrix = np.reshape(stats['Accuracy'].values,(len(mice),-1)).T
F1_matrix = np.reshape(stats['F1'].values,(len(mice),-1)).T
# Out:
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          211.0          128.0
# True YES          41.0           40.0
#
# F1: 0.321
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3135.0         2869.0
# True YES         297.0          292.0
#
# F1: 0.156
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3472.0         2848.0
# True YES         226.0          218.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.55
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          511.0          751.0
# True YES          66.0           68.0
#
# F1: 0.143
#
# Accuracy on class 0: 0.40
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3777.0         3365.0
# True YES         338.0          330.0
#
# F1: 0.151
#
# Accuracy on class 0: 0.53
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          515.0          562.0
# True YES          90.0           91.0
#
# F1: 0.218
#
# Accuracy on class 0: 0.48
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2639.0         2554.0
# True YES         224.0          221.0
#
# F1: 0.137
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2634.0         1992.0
# True YES         437.0          427.0
#
# F1: 0.260
#
# Accuracy on class 0: 0.57
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2160.0         1681.0
# True YES         216.0          211.0
#
# F1: 0.182
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2744.0         2565.0
# True YES         288.0          279.0
#
# F1: 0.164
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.406149
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1744.0         1104.0
# True YES         243.0          241.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          229.0          110.0
# True YES          48.0           33.0
#
# F1: 0.295
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3734.0         2270.0
# True YES         439.0          150.0
#
# F1: 0.100
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4000.0         2320.0
# True YES         328.0          116.0
#
# F1: 0.081
#
# Accuracy on class 0: 0.63
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          728.0          534.0
# True YES          98.0           36.0
#
# F1: 0.102
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4486.0         2656.0
# True YES         501.0          167.0
#
# F1: 0.096
#
# Accuracy on class 0: 0.63
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          626.0          451.0
# True YES         131.0           50.0
#
# F1: 0.147
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3202.0         1991.0
# True YES         361.0           84.0
#
# F1: 0.067
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2883.0         1743.0
# True YES         571.0          293.0
#
# F1: 0.202
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2444.0         1397.0
# True YES         306.0          121.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.64
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3216.0         2093.0
# True YES         429.0          138.0
#
# F1: 0.099
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.229898
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1873.0          975.0
# True YES         304.0          180.0
#
# F1: 0.220
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.37
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          241.0           98.0
# True YES          51.0           30.0
#
# F1: 0.287
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.37
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4428.0         1576.0
# True YES         452.0          137.0
#
# F1: 0.119
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4706.0         1614.0
# True YES         342.0          102.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          919.0          343.0
# True YES         101.0           33.0
#
# F1: 0.129
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5210.0         1932.0
# True YES         525.0          143.0
#
# F1: 0.104
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          733.0          344.0
# True YES         139.0           42.0
#
# F1: 0.148
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3826.0         1367.0
# True YES         375.0           70.0
#
# F1: 0.074
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3146.0         1480.0
# True YES         597.0          267.0
#
# F1: 0.205
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2752.0         1089.0
# True YES         318.0          109.0
#
# F1: 0.134
#
# Accuracy on class 0: 0.72
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3863.0         1446.0
# True YES         445.0          122.0
#
# F1: 0.114
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.180656
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2023.0          825.0
# True YES         326.0          158.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.33
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          334.0            5.0
# True YES          81.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5960.0           44.0
# True YES         583.0            6.0
#
# F1: 0.019
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6257.0           63.0
# True YES         429.0           15.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.03
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1254.0            8.0
# True YES         132.0            2.0
#
# F1: 0.028
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         7058.0           84.0
# True YES         654.0           14.0
#
# F1: 0.037
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1070.0            7.0
# True YES         180.0            1.0
#
# F1: 0.011
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5142.0           51.0
# True YES         440.0            5.0
#
# F1: 0.020
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4551.0           75.0
# True YES         847.0           17.0
#
# F1: 0.036
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3804.0           37.0
# True YES         420.0            7.0
#
# F1: 0.030
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.02
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5253.0           56.0
# True YES         559.0            8.0
#
# F1: 0.025
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.01
#
# Optimization terminated successfully.
#          Current function value: 0.261225
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2791.0           57.0
# True YES         462.0           22.0
#
# F1: 0.078
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          226.0          113.0
# True YES          48.0           33.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.67
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3600.0         2404.0
# True YES         430.0          159.0
#
# F1: 0.101
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3869.0         2451.0
# True YES         325.0          119.0
#
# F1: 0.079
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          687.0          575.0
# True YES          95.0           39.0
#
# F1: 0.104
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4370.0         2772.0
# True YES         498.0          170.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          601.0          476.0
# True YES         126.0           55.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.30
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3110.0         2083.0
# True YES         359.0           86.0
#
# F1: 0.066
#
# Accuracy on class 0: 0.60
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2853.0         1773.0
# True YES         571.0          293.0
#
# F1: 0.200
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2379.0         1462.0
# True YES         303.0          124.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3125.0         2184.0
# True YES         431.0          136.0
#
# F1: 0.094
#
# Accuracy on class 0: 0.59
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.237481
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1856.0          992.0
# True YES         301.0          183.0
#
# F1: 0.221
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.38
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          267.0           72.0
# True YES          45.0           36.0
#
# F1: 0.381
#
# Accuracy on class 0: 0.79
# Accuracy on class 1: 0.44
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4497.0         1507.0
# True YES         320.0          269.0
#
# F1: 0.227
#
# Accuracy on class 0: 0.75
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4890.0         1430.0
# True YES         241.0          203.0
#
# F1: 0.195
#
# Accuracy on class 0: 0.77
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          859.0          403.0
# True YES          79.0           55.0
#
# F1: 0.186
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5313.0         1829.0
# True YES         372.0          296.0
#
# F1: 0.212
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.44
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          770.0          307.0
# True YES          98.0           83.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3808.0         1385.0
# True YES         233.0          212.0
#
# F1: 0.208
#
# Accuracy on class 0: 0.73
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3537.0         1089.0
# True YES         500.0          364.0
#
# F1: 0.314
#
# Accuracy on class 0: 0.76
# Accuracy on class 1: 0.42
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2968.0          873.0
# True YES         242.0          185.0
#
# F1: 0.249
#
# Accuracy on class 0: 0.77
# Accuracy on class 1: 0.43
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3945.0         1364.0
# True YES         304.0          263.0
#
# F1: 0.240
#
# Accuracy on class 0: 0.74
# Accuracy on class 1: 0.46
#
# Optimization terminated successfully.
#          Current function value: 0.330543
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2228.0          620.0
# True YES         286.0          198.0
#
# F1: 0.304
#
# Accuracy on class 0: 0.78
# Accuracy on class 1: 0.41
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          285.0           54.0
# True YES          74.0            7.0
#
# F1: 0.099
#
# Accuracy on class 0: 0.84
# Accuracy on class 1: 0.09
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5552.0          452.0
# True YES         553.0           36.0
#
# F1: 0.067
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5950.0          370.0
# True YES         420.0           24.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1187.0           75.0
# True YES         123.0           11.0
#
# F1: 0.100
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6600.0          542.0
# True YES         633.0           35.0
#
# F1: 0.056
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          962.0          115.0
# True YES         173.0            8.0
#
# F1: 0.053
#
# Accuracy on class 0: 0.89
# Accuracy on class 1: 0.04
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4857.0          336.0
# True YES         430.0           15.0
#
# F1: 0.038
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.03
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3979.0          647.0
# True YES         792.0           72.0
#
# F1: 0.091
#
# Accuracy on class 0: 0.86
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3481.0          360.0
# True YES         395.0           32.0
#
# F1: 0.078
#
# Accuracy on class 0: 0.91
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4929.0          380.0
# True YES         545.0           22.0
#
# F1: 0.045
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.04
#
# Optimization terminated successfully.
#          Current function value: 0.216683
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2465.0          383.0
# True YES         418.0           66.0
#
# F1: 0.141
#
# Accuracy on class 0: 0.87
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          209.0          130.0
# True YES          40.0           41.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3087.0         2917.0
# True YES         296.0          293.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3414.0         2906.0
# True YES         225.0          219.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          495.0          767.0
# True YES          66.0           68.0
#
# F1: 0.140
#
# Accuracy on class 0: 0.39
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3705.0         3437.0
# True YES         335.0          333.0
#
# F1: 0.150
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          503.0          574.0
# True YES          90.0           91.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.47
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2586.0         2607.0
# True YES         224.0          221.0
#
# F1: 0.135
#
# Accuracy on class 0: 0.50
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2597.0         2029.0
# True YES         434.0          430.0
#
# F1: 0.259
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2139.0         1702.0
# True YES         216.0          211.0
#
# F1: 0.180
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2694.0         2615.0
# True YES         287.0          280.0
#
# F1: 0.162
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.364975
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1732.0         1116.0
# True YES         241.0          243.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          223.0          116.0
# True YES          40.0           41.0
#
# F1: 0.345
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3531.0         2473.0
# True YES         306.0          283.0
#
# F1: 0.169
#
# Accuracy on class 0: 0.59
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3845.0         2475.0
# True YES         235.0          209.0
#
# F1: 0.134
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.47
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          618.0          644.0
# True YES          70.0           64.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.49
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4177.0         2965.0
# True YES         349.0          319.0
#
# F1: 0.161
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          586.0          491.0
# True YES          92.0           89.0
#
# F1: 0.234
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2954.0         2239.0
# True YES         225.0          220.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.57
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2847.0         1779.0
# True YES         443.0          421.0
#
# F1: 0.275
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2366.0         1475.0
# True YES         221.0          206.0
#
# F1: 0.195
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.48
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3065.0         2244.0
# True YES         290.0          277.0
#
# F1: 0.179
#
# Accuracy on class 0: 0.58
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.261658
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1852.0          996.0
# True YES         248.0          236.0
#
# F1: 0.275
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          240.0           99.0
# True YES          55.0           26.0
#
# F1: 0.252
#
# Accuracy on class 0: 0.71
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4138.0         1866.0
# True YES         492.0           97.0
#
# F1: 0.076
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4393.0         1927.0
# True YES         374.0           70.0
#
# F1: 0.057
#
# Accuracy on class 0: 0.70
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          837.0          425.0
# True YES         110.0           24.0
#
# F1: 0.082
#
# Accuracy on class 0: 0.66
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4935.0         2207.0
# True YES         550.0          118.0
#
# F1: 0.079
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          702.0          375.0
# True YES         150.0           31.0
#
# F1: 0.106
#
# Accuracy on class 0: 0.65
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3580.0         1613.0
# True YES         394.0           51.0
#
# F1: 0.048
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.11
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3100.0         1526.0
# True YES         664.0          200.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.67
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2641.0         1200.0
# True YES         349.0           78.0
#
# F1: 0.091
#
# Accuracy on class 0: 0.69
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3597.0         1712.0
# True YES         485.0           82.0
#
# F1: 0.069
#
# Accuracy on class 0: 0.68
# Accuracy on class 1: 0.14
#
# Optimization terminated successfully.
#          Current function value: 0.255366
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1988.0          860.0
# True YES         345.0          139.0
#
# F1: 0.187
#
# Accuracy on class 0: 0.70
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          209.0          130.0
# True YES          40.0           41.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.62
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3087.0         2917.0
# True YES         296.0          293.0
#
# F1: 0.154
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3414.0         2906.0
# True YES         225.0          219.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.54
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          495.0          767.0
# True YES          66.0           68.0
#
# F1: 0.140
#
# Accuracy on class 0: 0.39
# Accuracy on class 1: 0.51
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3705.0         3437.0
# True YES         335.0          333.0
#
# F1: 0.150
#
# Accuracy on class 0: 0.52
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          503.0          574.0
# True YES          90.0           91.0
#
# F1: 0.215
#
# Accuracy on class 0: 0.47
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2586.0         2607.0
# True YES         224.0          221.0
#
# F1: 0.135
#
# Accuracy on class 0: 0.50
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2597.0         2029.0
# True YES         434.0          430.0
#
# F1: 0.259
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.50
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2139.0         1702.0
# True YES         216.0          211.0
#
# F1: 0.180
#
# Accuracy on class 0: 0.56
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2694.0         2615.0
# True YES         287.0          280.0
#
# F1: 0.162
#
# Accuracy on class 0: 0.51
# Accuracy on class 1: 0.49
#
# Optimization terminated successfully.
#          Current function value: 0.354096
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1732.0         1116.0
# True YES         241.0          243.0
#
# F1: 0.264
#
# Accuracy on class 0: 0.61
# Accuracy on class 1: 0.50

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.heatmap(acc_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('Accuracy')

plt.subplot(122)
sns.heatmap(F1_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('F1')

# %%
data_80.head(2)
# Out:
#    Condition Mouse ID   Session ID  Block Trial  Port Streak  Reward Streak  \
# 0        0.8       K1  11212016_K1         11.0          1.0            1.0
# 1        0.8       K1  11212016_K1         12.0          2.0            2.0
#
#    10_Port  10_Reward  10_ITI  10_trialDuration   ...    2_trialDuration  \
# 0     -1.0        1.0   1.993             0.727   ...              0.524
# 1     -1.0        1.0   1.729             0.894   ...              0.573
#
#    1_Port  1_Reward  1_ITI  1_trialDuration  0_ITI  Decision  Switch  \
# 0    -1.0       1.0  1.303            0.573  1.952       0.0     0.0
# 1    -1.0       1.0  1.952            0.445  2.681       0.0     0.0
#
#    Higher p port  Reward
# 0            1.0     1.0
# 1            1.0     1.0
#
# [2 rows x 51 columns]

# %%
u_switch = np.zeros(len(mice))
u_acc = np.zeros(len(mice))

for i,mouse in enumerate(mice):
    u_switch[i] = data_80[data_80['Mouse ID']== mouse]['Switch'].mean()
    u_acc[i] = data_80[data_80['Mouse ID']== mouse]['Higher p port'].mean()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates anti-correlate with accuracy on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as test mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Testing accuracy vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as train mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Training accuracy vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates correlate with F1 score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Better behavior correlates with accuracy score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing Acc vs mean p(high p port)')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training acc vs mean p(high p port)')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('p(high p port) vs F1 score',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()
