# %% [markdown]
# # Logistic Regression
#
# This logistic regression is based on the Beeler/Daw et al. 2010 paper.
# Specifically:
#
# dependent variable: binary choice of port (-1 or 1)
#
# explanatory variables:
# 1. the N previous rewards $ r_{t-N:t-1} $
# 2. the previous choice $c_{t-1}$ to capture a tendency to stay or switch
# 3. bias variable (1) to capture fixed, overall preference for either port
#
# Note: this model only carries information about ports when it gets a reward. IE -1 = right reward, 1 = left reward, but 0 = no reward (for either side). Should compare models with this information vs. added information about the non-rewarded port choices.

# %% [markdown]
# ## 02/19/2017
# I just ran the above code on the following data:
#
# - `full_9010_02192017.csv`
# - `full_8020_02192017.csv`
# - `full_7030_02192017.csv`
#
# Which were computed by compiling the following data:
# - block range: exactly 50 rewards
# - p(choose high Port) >= [p-0.1] where p = p(high Port)
#
# Observations:
# 1. pseudo-R2 also similar: ~0.64-0.69
# 2. For (1)  maybe a slight trend that 90-10 had a better model, but not certain.
# 3. For each condition, I tried adding in more ports (up to 3) into the past to see if it would help out. For all 3 conditions, decisions for t-N where 2 >= 2 had coefficients = 0. That is, the only non-zero beta for the ports was the most recent one.
#
# Next step:
#
#
# **Figures**
#
# 1. Logistic regression performs similarly across different conditions
#     - x axis: 90-10,80-20,70-30
#     - y axis: F1 score, pseudo-R2
# 2. Comparing model flexibility across different conditions
#     - x axis: number of previous rewards included (i.e. parameters in model)
#     - y axis: BIC
#     - color: each condition
# 3. Knowing where the non-rewarded trials are:
#     - what if you did the same regression, but instead you know where the non-rewarded trials are?
#     - also, compare to adding in previous ports (or rewards in the above scenario) and compare
#
# 4. Comparing 'strategies' across conditions
#     - train on 90-10, test on 80-20 (and all combinations)
#
# 5. Comparing 'strategies' across mice
#     - train on one mouse:condition pair, and test on another mouse:condition pair (for the same condition)

# %%
import sys
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sklearn.linear_model
import sklearn.tree
# %matplotlib inline

# %% [markdown]
# ## define function to do logistic regression and some basic evalutions

# %%
'''
I compiled the code above into a more compact function so I can cycle through different conditions/mice/etc 
as neccessary
'''

def logreg_and_eval(data,num_rewards=10,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    d = data.copy()
    for i in range(len(port_features)):
        d[reward_features[i]] = d[reward_features[i]].values*d[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    features.append('1_Port') #append the last decision as a feature
    features.append('Decision') #finally append the decision so we can take it to predict later
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            data_test_new[reward_features[i]] = test_data[reward_features[i]].values*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = d_test['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = d['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'stay':acc_pos,'switch':acc_neg,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features.append('Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %%
def logreg_and_eval_withports(data,num_rewards=10,num_ports=1,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix)
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    d = data.copy()
    for i in range(len(port_features)):
        d[reward_features[i]] = d[reward_features[i]].values*d[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    if num_rewards == 0:
        features = port_features[-1*num_ports:]
    elif num_ports == 0:
        features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    else:
        features = features[-1*num_rewards:]
        features = np.append(features,port_features[-1*num_ports:])
    
    print(features)
    features = np.append(features,'Decision') #finally append the decision so we can take it to predict later
    
    
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            data_test_new[reward_features[i]] = test_data[reward_features[i]].values*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = test_data['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = data['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'stay':acc_pos,'switch':acc_neg,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features = np.append(features,'Bias')
    
    coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=features)
    return logreg,stats,coefs

# %% [markdown]
# # Write here

# %%
data_90 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_9010_02192017.csv',index_col=0)
data_80 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_8020_02192017.csv',index_col=0)
data_70 = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/data/processed_data/full_7030_02192017.csv',index_col=0)

datas = [data_70,data_80,data_90]
models = []

# %%
for i,d in enumerate(datas):
    
    for j in range(30):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=7)
        models.append(models)

        if ((i == 0 and j == 0)):
            stats = stats_curr.copy()
            coefs = coefs_curr.copy()
        else:
            stats = stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

c = np.zeros(90)+70
c[30:] = 80
c[60:] = 90

stats.insert(0,'Condition',c)
coefs.insert(0,'Condition',c)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.241744
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4852.0           25.0
# True YES         456.0           24.0
#
# F1: 0.091
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.239710
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4856.0           19.0
# True YES         458.0           24.0
#
# F1: 0.091
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.234558
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4818.0           36.0
# True YES         476.0           27.0
#
# F1: 0.095
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.236607
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4819.0           25.0
# True YES         494.0           19.0
#
# F1: 0.068
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.04
#
# Optimization terminated successfully.
#          Current function value: 0.244313
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4862.0           25.0
# True YES         448.0           22.0
#
# F1: 0.085
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.238740
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4819.0           35.0
# True YES         480.0           23.0
#
# F1: 0.082
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.236742
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4823.0           40.0
# True YES         461.0           33.0
#
# F1: 0.116
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.237558
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4810.0           42.0
# True YES         468.0           37.0
#
# F1: 0.127
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.235204
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4824.0           15.0
# True YES         492.0           26.0
#
# F1: 0.093
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.237443
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4829.0           31.0
# True YES         474.0           23.0
#
# F1: 0.083
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.239424
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4841.0           33.0
# True YES         450.0           33.0
#
# F1: 0.120
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.239986
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4853.0           24.0
# True YES         457.0           23.0
#
# F1: 0.087
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.238102
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4835.0           22.0
# True YES         464.0           36.0
#
# F1: 0.129
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.235427
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4818.0           40.0
# True YES         465.0           34.0
#
# F1: 0.119
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.235702
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4829.0           36.0
# True YES         455.0           37.0
#
# F1: 0.131
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.238567
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4818.0           49.0
# True YES         451.0           39.0
#
# F1: 0.135
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0.237888
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4834.0           27.0
# True YES         465.0           31.0
#
# F1: 0.112
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.243815
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4865.0           23.0
# True YES         453.0           16.0
#
# F1: 0.063
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.03
#
# Optimization terminated successfully.
#          Current function value: 0.243407
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4869.0           27.0
# True YES         440.0           21.0
#
# F1: 0.083
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.235665
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4805.0           43.0
# True YES         476.0           33.0
#
# F1: 0.113
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.241778
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4856.0           19.0
# True YES         454.0           28.0
#
# F1: 0.106
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.241680
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4848.0           31.0
# True YES         450.0           28.0
#
# F1: 0.104
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.240478
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4844.0           19.0
# True YES         466.0           28.0
#
# F1: 0.104
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.236036
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4837.0           37.0
# True YES         451.0           32.0
#
# F1: 0.116
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.244230
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4868.0           37.0
# True YES         423.0           29.0
#
# F1: 0.112
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.241454
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4841.0           29.0
# True YES         462.0           25.0
#
# F1: 0.092
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# Optimization terminated successfully.
#          Current function value: 0.242709
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4851.0           31.0
# True YES         439.0           36.0
#
# F1: 0.133
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# Optimization terminated successfully.
#          Current function value: 0
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2936.0           42.0
# True YES         217.0           41.0
#
# F1: 0.240
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.220151
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2926.0           40.0
# True YES         213.0           57.0
#
# F1: 0.311
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.218620
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2938.0           35.0
# True YES         221.0           42.0
#
# F1: 0.247
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.216860
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2927.0           47.0
# True YES         219.0           43.0
#
# F1: 0.244
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.206754
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2902.0           33.0
# True YES         248.0           53.0
#
# F1: 0.274
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.215363
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2925.0           46.0
# True YES         213.0           52.0
#
# F1: 0.287
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.216610
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2916.0           38.0
# True YES         233.0           49.0
#
# F1: 0.266
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.212986
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2908.0           42.0
# True YES         239.0           47.0
#
# F1: 0.251
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.211848
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2889.0           60.0
# True YES         230.0           57.0
#
# F1: 0.282
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.210369
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2890.0           45.0
# True YES         243.0           58.0
#
# F1: 0.287
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.219467
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2937.0           35.0
# True YES         216.0           48.0
#
# F1: 0.277
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.213159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2924.0           41.0
# True YES         229.0           42.0
#
# F1: 0.237
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.15
#
# Optimization terminated successfully.
#          Current function value: 0.215018
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2916.0           53.0
# True YES         217.0           50.0
#
# F1: 0.270
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.210372
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2893.0           43.0
# True YES         248.0           52.0
#
# F1: 0.263
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.215344
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2914.0           39.0
# True YES         222.0           61.0
#
# F1: 0.319
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.210644
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2916.0           38.0
# True YES         234.0           48.0
#
# F1: 0.261
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.221151
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2933.0           64.0
# True YES         191.0           48.0
#
# F1: 0.274
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.216843
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2914.0           43.0
# True YES         215.0           64.0
#
# F1: 0.332
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.212440
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2917.0           49.0
# True YES         225.0           45.0
#
# F1: 0.247
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.220940
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2930.0           51.0
# True YES         194.0           61.0
#
# F1: 0.332
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.211132
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2903.0           46.0
# True YES         232.0           55.0
#
# F1: 0.284
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.216257
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2918.0           50.0
# True YES         212.0           56.0
#
# F1: 0.299
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.209528
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2898.0           35.0
# True YES         250.0           53.0
#
# F1: 0.271
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.213803
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2918.0           49.0
# True YES         215.0           54.0
#
# F1: 0.290
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.216314
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2904.0           52.0
# True YES         224.0           56.0
#
# F1: 0.289
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.211910
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2901.0           45.0
# True YES         246.0           44.0
#
# F1: 0.232
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0
# 0        90.0  0.911928  3235.307902             1581.936740   0.697415
# 0        90.0  0.918418  3299.865993             1614.215785   0.691209
# 0        90.0  0.914710  3337.782527             1633.174052   0.687740
# 0        90.0  0.910074  3271.268407             1599.916992   0.693737
#
#         stay    switch
# 0   0.050000  0.994874
# 0   0.049793  0.996103
# 0   0.053678  0.992583
# 0   0.037037  0.994839
# 0   0.046809  0.994884
# 0   0.045726  0.992789
# 0   0.066802  0.991775
# 0   0.073267  0.991344
# 0   0.050193  0.996900
# 0   0.046278  0.993621
# 0   0.068323  0.993229
# 0   0.047917  0.995079
# 0   0.072000  0.995470
# 0   0.068136  0.991766
# 0   0.075203  0.992600
# 0   0.079592  0.989932
# 0   0.062500  0.994446
# 0   0.034115  0.995295
# 0   0.045553  0.994485
# 0   0.064833  0.991130
# 0   0.058091  0.996103
# 0   0.058577  0.993646
# 0   0.056680  0.996093
# 0   0.066253  0.992409
# 0   0.064159  0.992457
# 0   0.051335  0.994045
# 0   0.075789  0.993650
# 0   0.060784  0.992366
# 0   0.052738  0.992393
# 0   0.053435  0.991930
# ..       ...       ...
# 0   0.191126  0.982671
# 0   0.195122  0.985080
# 0   0.189189  0.984548
# 0   0.203008  0.984848
# 0   0.158915  0.985897
# 0   0.211111  0.986514
# 0   0.159696  0.988227
# 0   0.164122  0.984196
# 0   0.176080  0.988756
# 0   0.196226  0.984517
# 0   0.173759  0.987136
# 0   0.164336  0.985763
# 0   0.198606  0.979654
# 0   0.192691  0.984668
# 0   0.181818  0.988223
# 0   0.154982  0.986172
# 0   0.187266  0.982149
# 0   0.173333  0.985354
# 0   0.215548  0.986793
# 0   0.170213  0.987136
# 0   0.200837  0.978645
# 0   0.229391  0.985458
# 0   0.166667  0.983479
# 0   0.239216  0.982892
# 0   0.191638  0.984401
# 0   0.208955  0.983154
# 0   0.174917  0.988067
# 0   0.200743  0.983485
# 0   0.200000  0.982409
# 0   0.151724  0.984725
#
# [90 rows x 7 columns]

# %%
acc_9010 = stats[stats['Condition']==70]['stay'].mean()

# %%
acc_9010
# Out:
# 0.057853209795639314

# %%
d = {'condition':['90-10','90-10','90-10','80-20','80-20','80-20','70-30','70-30','70-30'],
    'accuracy': [0.91,0.98,0.18,0.90,0.99,0.10,0.90,0.99,0.05],
     'type':['overall','stay','switch','overall','stay','switch','overall','stay','switch']
    }

# %%
master_stats = pd.DataFrame(data=d,index=None)
sns.set_style('whitegrid')
sns.barplot(x='condition',y='accuracy',data=master_stats,hue='type',palette='husl')
plt.legend(bbox_to_anchor=(1.3,1))

# %% [markdown]
# # Comparing beta coefficients across conditions

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(12,4))
gs = gridspec.GridSpec(1,4,width_ratios=[2,1,1,1])

plt.subplot(gs[0])
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='red',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='green',alpha=0.5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='navy',alpha=0.5)

plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
            color='red',label='90-10',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
            color='green',label='80-20',s=50)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
            color='navy',label='70-30',s=50)

plt.legend(loc='upper left')
plt.xticks(np.arange(coefs.shape[1]),coefs.columns.values[1:],rotation='vertical')
plt.xlim(-0.5,8.5)
plt.title('Regression Coefficients')

plt.subplot(gs[1])
sns.barplot(x='Condition',y='Accuracy',data=stats)
plt.title('Accuracy (test)')
plt.xticks([0,1,2],['70','80','90'],fontsize=20)
plt.yticks([0.7,0.8,0.9,1.0],fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylim(0.7,1)

plt.subplot(gs[2])
sns.barplot(x='Condition',y='F1',data=stats)
plt.title('F1 (test)')
#plt.ylim(0.7,1)

plt.subplot(gs[3])
sns.barplot(x='Condition',y='pseudo-R2',data=stats)
plt.title('pseudo-R2')
plt.ylim(0.5,0.8)

plt.tight_layout()

# %%
sns.set_style('white')
plt.figure(figsize=(15,6))
gs = gridspec.GridSpec(1,2,width_ratios=[3,1])

plt.subplot(gs[0])
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='red',alpha=0.5,linewidth=5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='green',alpha=0.5,linewidth=5)
plt.errorbar(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
             yerr= coefs[coefs['Condition'] == 90].iloc[:,1:].mean() / np.sqrt(np.sum(coefs['Condition'] == 90)),
             color='navy',alpha=0.5,linewidth=5)

plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 90].iloc[:,1:].mean(),
            color='red',label='90-10',s=100)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 80].iloc[:,1:].mean(),
            color='green',label='80-20',s=100)
plt.scatter(np.arange(coefs.shape[1]-1),coefs[coefs['Condition'] == 70].iloc[:,1:].mean(),
            color='navy',label='70-30',s=100)

plt.legend(loc='upper left',fontsize=20)
#plt.xticks(np.arange(coefs.shape[1]),coefs.columns.values[1:],rotation='vertical')
plt.xlabel('')
plt.yticks([0,1,2],fontsize=20)
plt.ylabel('coefficient value',fontsize=20)
plt.xlim(-0.5,8.5)
plt.title('Regression Coefficients',fontsize=20)

plt.subplot(gs[1])
sns.barplot(x='Condition',y='Accuracy',data=stats)
plt.title('Accuracy',fontsize=20)
plt.xticks([0,1,2],['70','80','90'],fontsize=20)
plt.yticks([0.7,0.8,0.9,1.0],fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylabel('')
plt.ylim(0.7,1)

plt.tight_layout()

# %% [markdown]
# ## Test number of parameters / model flexibility vs BIC

# %%
stats.head(2)
# Out:
#    Condition  Accuracy          BIC        F1  negative loglikelihood  \
# 0       70.0  0.909838  6035.178663  0.065764             2979.855716
# 0       70.0  0.909091  6034.395852  0.086304             2979.464311
#
#    pseudo-R2
# 0   0.656046
# 0   0.656057

# %%
d = data_80.copy()
stats = pd.DataFrame(columns=['Accuracy','BIC','negative loglikelihood','pseudo-R2','No. parameters'])

for i,n in enumerate(np.arange(10,0,-1)):
    
    for j in enumerate(range(30)):
        model_curr,stats_curr,coefs_curr = logreg_and_eval(d,num_rewards=n)
        models.append(models)
        stats_curr['No. parameters'] = n
        stats = stats.append(stats_curr)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.246039
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13017.0          177.0
# True YES        1272.0          188.0
#
# F1: 0.206
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.13
#
# Optimization terminated successfully.
#          Current function value: 0.246079
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13012.0          147.0
# True YES        1342.0          153.0
#
# F1: 0.170
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# Optimization terminated successfully.
#          Current function value: 0.246265
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13041.0          108.0
# True YES        1367.0          138.0
#
# F1: 0.158
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# Optimization terminated successfully.
#          Current function value: 0
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.252156
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13202.0            0.0
# True YES        1452.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.252580
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13082.0           98.0
# True YES        1389.0           85.0
#
# F1: 0.103
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.253382
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13102.0          105.0
# True YES        1340.0          107.0
#
# F1: 0.129
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.252327
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13071.0           91.0
# True YES        1391.0          101.0
#
# F1: 0.120
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.252335
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13093.0           83.0
# True YES        1382.0           96.0
#
# F1: 0.116
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# Optimization terminated successfully.
#          Current function value: 0.251452
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13096.0           92.0
# True YES        1369.0           97.0
#
# F1: 0.117
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.251241
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13086.0           86.0
# True YES        1384.0           98.0
#
# F1: 0.118
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.261792
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13161.0            0.0
# True YES        1493.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265754
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13203.0            0.0
# True YES        1451.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264669
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13185.0            0.0
# True YES        1469.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266601
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13226.0            0.0
# True YES        1428.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261517
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13154.0            0.0
# True YES        1500.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263361
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13183.0            0.0
# True YES        1471.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262043
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13164.0            0.0
# True YES        1490.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266381
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13240.0            0.0
# True YES        1414.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262993
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13179.0            0.0
# True YES        1475.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266957
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13242.0            0.0
# True YES        1412.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266032
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13225.0            0.0
# True YES        1429.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263725
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13156.0            0.0
# True YES        1498.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264814
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13188.0            0.0
# True YES        1466.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264172
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13179.0            0.0
# True YES        1475.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263656
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263817
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13172.0            0.0
# True YES        1482.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.266368
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13229.0            0.0
# True YES        1425.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263257
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13191.0            0.0
# True YES        1463.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261998
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13138.0            0.0
# True YES        1516.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.260380
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13097.0            0.0
# True YES        1557.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262897
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13163.0            0.0
# True YES        1491.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265329
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13218.0            0.0
# True YES        1436.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.261278
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13154.0            0.0
# True YES        1500.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.265543
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13212.0            0.0
# True YES        1442.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264569
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13197.0            0.0
# True YES        1457.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262824
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13189.0            0.0
# True YES        1465.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.262363
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13167.0            0.0
# True YES        1487.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264872
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13210.0            0.0
# True YES        1444.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.264266
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13197.0            0.0
# True YES        1457.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# Optimization terminated successfully.
#          Current function value: 0.263504
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13166.0            0.0
# True YES        1488.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00

# %%
plt.figure(figsize=(10,4))
sns.factorplot(x='No. parameters',y='BIC',data=stats,color='black')
plt.title('BIC vs model flexibility')

# %%
BIC = np.zeros((10,10))
F1 = np.zeros((10,10))
R2 = np.zeros((10,10))
acc = np.zeros((10,10))

for i in range(10):
    for j in range(10):
        if not ((j==0) & (i==0)):
            model_curr,stats_curr,coefs_curr = logreg_and_eval_withports(d,num_rewards=i,num_ports=j)
            BIC[i,j] = stats_curr['BIC'].values
            F1[i,j] = stats_curr['F1'].values
            R2[i,j] = stats_curr['pseudo-R2'].values
            acc[i,j] = stats_curr['Accuracy'].values
# Out:
# ['1_Port']
# Optimization terminated successfully.
#          Current function value: 0.324176
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13175.0            0.0
# True YES        1479.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.313950
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13193.0            0.0
# True YES        1461.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.310537
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13171.0            0.0
# True YES        1483.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.310104
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13199.0            0.0
# True YES        1455.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.310567
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13228.0            0.0
# True YES        1426.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.308569
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13217.0            0.0
# True YES        1437.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.308413
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13206.0            0.0
# True YES        1448.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.305045
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13182.0            0.0
# True YES        1472.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['9_Port', '8_Port', '7_Port', '6_Port', '5_Port', '4_Port', '3_Port', '2_Port', '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.306439
#          Iterations 6
#           Predicted NO  Predicted YES
# True NO        13181.0            0.0
# True YES        1473.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.301776
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        11669.0         1562.0
# True YES         841.0          582.0
#
# F1: 0.326
#
# Accuracy on class 0: 0.88
# Accuracy on class 1: 0.41
#
# ['1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.268725
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13241.0            0.0
# True YES        1413.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.256091
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13153.0            0.0
# True YES        1501.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.258960
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13223.0            0.0
# True YES        1431.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.255417
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13190.0            0.0
# True YES        1464.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.256097
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13102.0           96.0
# True YES        1354.0          102.0
#
# F1: 0.123
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['1_Reward' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.252846
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13055.0           96.0
# True YES        1407.0           96.0
#
# F1: 0.113
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['1_Reward' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.253143
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13103.0           92.0
# True YES        1366.0           93.0
#
# F1: 0.113
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['1_Reward' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.251881
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12985.0          160.0
# True YES        1347.0          162.0
#
# F1: 0.177
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['1_Reward' '9_Port' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.251384
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12978.0          164.0
# True YES        1356.0          156.0
#
# F1: 0.170
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.264028
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12522.0          689.0
# True YES         970.0          473.0
#
# F1: 0.363
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.33
#
# ['2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249855
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13174.0            0.0
# True YES        1480.0            0.0
#
# F1: 0.000
#
# Accuracy on class 0: 1.00
# Accuracy on class 1: 0.00
#
# ['2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.251676
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13105.0           94.0
# True YES        1359.0           96.0
#
# F1: 0.117
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.250380
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13133.0           81.0
# True YES        1369.0           71.0
#
# F1: 0.089
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.05
#
# ['2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248367
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13083.0           77.0
# True YES        1403.0           91.0
#
# F1: 0.110
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247257
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13083.0           82.0
# True YES        1395.0           94.0
#
# F1: 0.113
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.250504
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13143.0           76.0
# True YES        1350.0           85.0
#
# F1: 0.107
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248348
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13083.0           82.0
# True YES        1394.0           95.0
#
# F1: 0.114
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247088
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13077.0           89.0
# True YES        1392.0           96.0
#
# F1: 0.115
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249203
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13116.0           79.0
# True YES        1368.0           91.0
#
# F1: 0.112
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.06
#
# ['3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.255681
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12642.0          513.0
# True YES        1045.0          454.0
#
# F1: 0.368
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.30
#
# ['3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.250233
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13103.0           99.0
# True YES        1346.0          106.0
#
# F1: 0.128
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247895
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13036.0          121.0
# True YES        1354.0          143.0
#
# F1: 0.162
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248501
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13090.0          103.0
# True YES        1355.0          106.0
#
# F1: 0.127
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249919
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13097.0           96.0
# True YES        1361.0          100.0
#
# F1: 0.121
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.250379
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13127.0           80.0
# True YES        1346.0          101.0
#
# F1: 0.124
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248575
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13091.0          123.0
# True YES        1316.0          124.0
#
# F1: 0.147
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248090
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13043.0          121.0
# True YES        1342.0          148.0
#
# F1: 0.168
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247452
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13079.0          112.0
# True YES        1356.0          107.0
#
# F1: 0.127
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248669
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13076.0          115.0
# True YES        1339.0          124.0
#
# F1: 0.146
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.257457
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12728.0          496.0
# True YES         996.0          434.0
#
# F1: 0.368
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.30
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248919
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13055.0          133.0
# True YES        1343.0          123.0
#
# F1: 0.143
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249057
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13083.0          117.0
# True YES        1316.0          138.0
#
# F1: 0.161
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248546
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13088.0          114.0
# True YES        1316.0          136.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246525
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13049.0           96.0
# True YES        1389.0          120.0
#
# F1: 0.139
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248307
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13084.0          116.0
# True YES        1325.0          129.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248357
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13092.0           94.0
# True YES        1345.0          123.0
#
# F1: 0.146
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.243905
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13022.0           95.0
# True YES        1416.0          121.0
#
# F1: 0.138
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.243726
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13004.0          128.0
# True YES        1372.0          150.0
#
# F1: 0.167
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['4_Reward' '3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port'
#  '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246037
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13040.0          138.0
# True YES        1330.0          146.0
#
# F1: 0.166
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.255273
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12662.0          521.0
# True YES        1021.0          450.0
#
# F1: 0.369
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.31
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247909
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13066.0          105.0
# True YES        1355.0          128.0
#
# F1: 0.149
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246009
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13067.0          113.0
# True YES        1356.0          118.0
#
# F1: 0.138
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245546
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13053.0          118.0
# True YES        1359.0          124.0
#
# F1: 0.144
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246032
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13050.0           93.0
# True YES        1386.0          125.0
#
# F1: 0.145
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.08
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245438
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13037.0          122.0
# True YES        1362.0          133.0
#
# F1: 0.152
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245735
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13064.0          128.0
# True YES        1315.0          147.0
#
# F1: 0.169
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.244792
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13037.0          111.0
# True YES        1367.0          139.0
#
# F1: 0.158
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port'
#  '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248455
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13067.0          124.0
# True YES        1328.0          135.0
#
# F1: 0.157
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port'
#  '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246262
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13034.0          122.0
# True YES        1362.0          136.0
#
# F1: 0.155
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.254943
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12677.0          523.0
# True YES         992.0          462.0
#
# F1: 0.379
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248952
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13073.0          131.0
# True YES        1342.0          108.0
#
# F1: 0.128
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249521
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13078.0          175.0
# True YES        1235.0          166.0
#
# F1: 0.191
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247810
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13073.0          119.0
# True YES        1324.0          138.0
#
# F1: 0.161
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246369
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13033.0          146.0
# True YES        1323.0          152.0
#
# F1: 0.171
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249746
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13068.0          134.0
# True YES        1287.0          165.0
#
# F1: 0.188
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248910
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13066.0          142.0
# True YES        1301.0          145.0
#
# F1: 0.167
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '7_Port'
#  '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245531
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13041.0          110.0
# True YES        1360.0          143.0
#
# F1: 0.163
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '8_Port'
#  '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247785
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13035.0          136.0
# True YES        1328.0          155.0
#
# F1: 0.175
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '9_Port'
#  '8_Port' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247866
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13045.0          155.0
# True YES        1298.0          156.0
#
# F1: 0.177
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['7_Reward', '6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.254037
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12673.0          512.0
# True YES         992.0          477.0
#
# F1: 0.388
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245505
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13016.0          123.0
# True YES        1362.0          153.0
#
# F1: 0.171
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249057
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13078.0          127.0
# True YES        1301.0          148.0
#
# F1: 0.172
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249072
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13072.0          109.0
# True YES        1336.0          137.0
#
# F1: 0.159
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248720
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13090.0          132.0
# True YES        1297.0          135.0
#
# F1: 0.159
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247249
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13060.0          121.0
# True YES        1341.0          132.0
#
# F1: 0.153
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249905
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13028.0          183.0
# True YES        1281.0          162.0
#
# F1: 0.181
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249496
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13086.0          116.0
# True YES        1308.0          144.0
#
# F1: 0.168
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245178
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13013.0          130.0
# True YES        1348.0          163.0
#
# F1: 0.181
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward' '2_Reward'
#  '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246357
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13024.0          105.0
# True YES        1382.0          143.0
#
# F1: 0.161
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['8_Reward', '7_Reward', '6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.252439
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12649.0          521.0
# True YES        1015.0          469.0
#
# F1: 0.379
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247829
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13049.0          145.0
# True YES        1314.0          146.0
#
# F1: 0.167
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247935
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13055.0          127.0
# True YES        1330.0          142.0
#
# F1: 0.163
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.244413
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13010.0          135.0
# True YES        1360.0          149.0
#
# F1: 0.166
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247934
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13054.0          135.0
# True YES        1313.0          152.0
#
# F1: 0.174
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248653
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13085.0          141.0
# True YES        1292.0          136.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245148
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13008.0          117.0
# True YES        1374.0          155.0
#
# F1: 0.172
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246163
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13000.0          128.0
# True YES        1379.0          147.0
#
# F1: 0.163
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246172
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13057.0          133.0
# True YES        1332.0          132.0
#
# F1: 0.153
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward' '3_Reward'
#  '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246899
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13033.0          139.0
# True YES        1326.0          156.0
#
# F1: 0.176
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward', '8_Reward', '7_Reward', '6_Reward', '5_Reward', '4_Reward', '3_Reward', '2_Reward', '1_Reward']
# Optimization terminated successfully.
#          Current function value: 0.256561
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        12723.0          498.0
# True YES        1002.0          431.0
#
# F1: 0.365
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.30
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247126
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13042.0          134.0
# True YES        1313.0          165.0
#
# F1: 0.186
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247907
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13078.0          136.0
# True YES        1292.0          148.0
#
# F1: 0.172
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247064
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13055.0          155.0
# True YES        1280.0          164.0
#
# F1: 0.186
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.246958
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13044.0          136.0
# True YES        1334.0          140.0
#
# F1: 0.160
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '5_Port' '4_Port' '3_Port' '2_Port'
#  '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.248067
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13023.0          160.0
# True YES        1289.0          182.0
#
# F1: 0.201
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '6_Port' '5_Port' '4_Port' '3_Port'
#  '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.249050
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13076.0          153.0
# True YES        1258.0          167.0
#
# F1: 0.191
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '7_Port' '6_Port' '5_Port' '4_Port'
#  '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.251601
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13109.0          134.0
# True YES        1243.0          168.0
#
# F1: 0.196
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '8_Port' '7_Port' '6_Port' '5_Port'
#  '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.247371
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13048.0          164.0
# True YES        1278.0          164.0
#
# F1: 0.185
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.11
#
# ['9_Reward' '8_Reward' '7_Reward' '6_Reward' '5_Reward' '4_Reward'
#  '3_Reward' '2_Reward' '1_Reward' '9_Port' '8_Port' '7_Port' '6_Port'
#  '5_Port' '4_Port' '3_Port' '2_Port' '1_Port']
# Optimization terminated successfully.
#          Current function value: 0.245721
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13031.0          131.0
# True YES        1320.0          172.0
#
# F1: 0.192
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.12

# %%
plt.figure(figsize=(20,5))
plt.suptitle('Model behavior vs # of rewards and decisions included',x=0.5,y=1.05,fontsize=20)

plt.subplot(141)
sns.heatmap(BIC,vmin=15000,vmax=25000)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('BIC',fontsize=15)

plt.subplot(142)
sns.heatmap(F1)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('F1',fontsize=15)

plt.subplot(143)
sns.heatmap(R2,vmin=0.5)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('R2')

plt.subplot(144)
sns.heatmap(acc,vmin=0.8)
plt.xlabel('# previous decisions in model',fontsize=15)
plt.ylabel('# previous reward outcomes in model',fontsize=15)
plt.title('Accuracy')

plt.tight_layout()

# %% [markdown]
# # Training / testing on different conditions

# %% [markdown]
# ### 1. Train on 90-10, test on 80-20 and 70-30

# %%
for i,d in enumerate([data_90,data_80,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_90,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_90 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.215178
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2909.0           53.0
# True YES         216.0           58.0
#
# F1: 0.301
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.216107
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        42740.0         1221.0
# True YES        3758.0         1126.0
#
# F1: 0.311
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.216107
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        15852.0          361.0
# True YES        1350.0          293.0
#
# F1: 0.255
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.18

# %%
stats_90['Testing Condition'] = [90,80,70]
stats_90
# Out:
#    Accuracy        F1  Testing Condition
# 0  0.916873  0.301299                 90
# 0  0.898065  0.311437                 80
# 0  0.904178  0.255115                 70

# %% [markdown]
# So this is interesting - accuracy stays pretty much the same across conditions, but F1 goes way down. And if we take a look at the confusion tables above, we can see it is because the accuracy on the switches went down (and accuracy on stays went up.

# %% [markdown]
# ### 2. Train on 80-20

# %%
for i,d in enumerate([data_80,data_90,data_70]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_80,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_80 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_80['Testing Condition'] = [80,90,70]
stats_80
# Out:
# Optimization terminated successfully.
#          Current function value: 0.246867
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13070.0          123.0
# True YES        1325.0          136.0
#
# F1: 0.158
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.09
#
# Optimization terminated successfully.
#          Current function value: 0.247334
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         9640.0          235.0
# True YES         658.0          253.0
#
# F1: 0.362
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.247334
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        15851.0          362.0
# True YES        1348.0          295.0
#
# F1: 0.257
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.18
#    Accuracy        F1  Testing Condition
# 0  0.901187  0.158140                 80
# 0  0.917207  0.361687                 90
# 0  0.904234  0.256522                 70

# %% [markdown]
# ### 3. Train on 70-30

# %%
for i,d in enumerate([data_70,data_80,data_90]):
    
    if i == 0:
        model,stats,coefs = logreg_and_eval(d)
    else:
        model,stats_curr,coefs_curr = logreg_and_eval(data_70,test_data = d)
        
        stats = stats.append(stats_curr)
        coefs = coefs.append(coefs_curr)

stats_70 = stats.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)

stats_70['Testing Condition'] = [70,80,90]
stats_70
# Out:
# Optimization terminated successfully.
#          Current function value: 0.237905
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4844.0           27.0
# True YES         451.0           35.0
#
# F1: 0.128
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.07
#
# Optimization terminated successfully.
#          Current function value: 0.238406
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        42851.0         1110.0
# True YES        3808.0         1076.0
#
# F1: 0.304
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.238406
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         9649.0          226.0
# True YES         662.0          249.0
#
# F1: 0.359
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.27
#    Accuracy        F1  Testing Condition
# 0  0.910771  0.127737                 70
# 0  0.899314  0.304385                 80
# 0  0.917671  0.359307                 90

# %%
f1s = np.vstack((stats_90['F1'].values,
               stats_80['F1'].values[[1,0,2]],
               stats_70['F1'].values[[2,1,0]]))
sns.heatmap(f1s,vmin=0,vmax=0.4)
plt.xticks([0.5,1.5,2.5],['90','80','70'])
plt.yticks([0.5,1.5,2.5],['70','80','90'])
plt.ylabel('Testing Condition')
plt.xlabel('Training Condition')
plt.title('F1 scores when trained & tested on different conditions')

# %% [markdown]
# So if this is right, it means that the rules are different - what predicts a switch in 90-10 does not predict a switch in 80-20. But since most of the trials follow the last one, the accuracy doesn't drop very much. So it appears to be working fine, even though it is not.
#
# Can the difference be explained in the small differences in beta coefficient values? It must be ... what else is there? They seem similar enough that I'm surprised it makes such a difference.
#
# Let's go on to train and test on separate mice:

# %% [markdown]
# # Train/test on separate mice

# %% [markdown]
# First let's take a quick look at the mice's performances - specifically just at p(choose high P port):

# %%
data_90.insert(0,'Condition',0.9)
data_80.insert(0,'Condition',0.8)
data_70.insert(0,'Condition',0.7)

# %%
all_data = data_90.append(data_80)
all_data = all_data.append(data_70)
all_data.shape
# Out:
# (77487, 51)

# %%
sns.factorplot(x='Condition',y='Higher p port',hue='Mouse ID',data = all_data,legend=False,size=5,aspect=1.7)
plt.legend(bbox_to_anchor=(1.2,1))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.xlabel('Condition',fontsize=20)
plt.ylabel('rate higher prob port chosen',fontsize=20)
plt.title('Average p(choose better port) for each mouse across conditions',fontsize=20,x=0.5,y=1.1)

# %% [markdown]
# Okay, so based on this. Let's start with 80-20, and do a few different comparisons.
#
# 1. Start by training with harry, and testing on all the others.
# 2. Then try training on volde, testing on all others.
# 3. Finally train on someone in the middle - like Tom or q45, and test on others

# %%
'''
Loop through mice
'''
mice = np.unique(data_80['Mouse ID'].values)

stats = pd.DataFrame(columns=['Accuracy','F1','Training Mouse','Testing Mouse'])
test_mice = []
train_mice = []

for mouse_train in mice:

    d_train = data_80[data_80['Mouse ID'] == mouse_train].copy()

    for i,mouse_test in enumerate(mice):
        d_test = data_80[data_80['Mouse ID'] == mouse_test].copy()

        if i == 0:
            model,stats_curr,coefs = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats = stats.append(stats_curr)
        else:
            model,stats_curr,coefs_curr = logreg_and_eval(d_train,test_data = d_test)
            stats_curr = stats_curr.drop(['BIC','negative loglikelihood','pseudo-R2'],axis=1)
            stats= stats.append(stats_curr)
            coefs = coefs.append(coefs_curr)

        test_mice.append(mouse_test)
        train_mice.append(mouse_train)

stats['Testing Mouse'] = test_mice
stats['Training Mouse'] = train_mice
acc_matrix = np.reshape(stats['Accuracy'].values,(len(mice),-1)).T
F1_matrix = np.reshape(stats['F1'].values,(len(mice),-1)).T
# Out:
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          323.0           16.0
# True YES          50.0           31.0
#
# F1: 0.484
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.38
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5755.0          249.0
# True YES         417.0          172.0
#
# F1: 0.341
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6167.0          153.0
# True YES         328.0          116.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1201.0           61.0
# True YES          89.0           45.0
#
# F1: 0.375
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6819.0          323.0
# True YES         476.0          192.0
#
# F1: 0.325
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          996.0           81.0
# True YES         126.0           55.0
#
# F1: 0.347
#
# Accuracy on class 0: 0.92
# Accuracy on class 1: 0.30
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4902.0          291.0
# True YES         319.0          126.0
#
# F1: 0.292
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4379.0          247.0
# True YES         612.0          252.0
#
# F1: 0.370
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3683.0          158.0
# True YES         321.0          106.0
#
# F1: 0.307
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5061.0          248.0
# True YES         394.0          173.0
#
# F1: 0.350
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.383550
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2714.0          134.0
# True YES         368.0          116.0
#
# F1: 0.316
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          324.0           15.0
# True YES          55.0           26.0
#
# F1: 0.426
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5855.0          149.0
# True YES         449.0          140.0
#
# F1: 0.319
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6235.0           85.0
# True YES         348.0           96.0
#
# F1: 0.307
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1227.0           35.0
# True YES          98.0           36.0
#
# F1: 0.351
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6963.0          179.0
# True YES         524.0          144.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1035.0           42.0
# True YES         135.0           46.0
#
# F1: 0.342
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5037.0          156.0
# True YES         348.0           97.0
#
# F1: 0.278
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4456.0          170.0
# True YES         650.0          214.0
#
# F1: 0.343
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3744.0           97.0
# True YES         344.0           83.0
#
# F1: 0.273
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5155.0          154.0
# True YES         424.0          143.0
#
# F1: 0.331
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.215159
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2754.0           94.0
# True YES         381.0          103.0
#
# F1: 0.302
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO          322.0           17.0
# True YES          53.0           28.0
#
# F1: 0.444
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.35
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5842.0          162.0
# True YES         444.0          145.0
#
# F1: 0.324
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         6227.0           93.0
# True YES         337.0          107.0
#
# F1: 0.332
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         1216.0           46.0
# True YES          93.0           41.0
#
# F1: 0.371
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         6896.0          246.0
# True YES         504.0          164.0
#
# F1: 0.304
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         1032.0           45.0
# True YES         132.0           49.0
#
# F1: 0.356
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5013.0          180.0
# True YES         330.0          115.0
#
# F1: 0.311
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         4455.0          171.0
# True YES         646.0          218.0
#
# F1: 0.348
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         3722.0          119.0
# True YES         335.0           92.0
#
# F1: 0.288
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         5153.0          156.0
# True YES         411.0          156.0
#
# F1: 0.355
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.162050
#          Iterations 9
#           Predicted NO  Predicted YES
# True NO         2739.0          109.0
# True YES         364.0          120.0
#
# F1: 0.337
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          326.0           13.0
# True YES          55.0           26.0
#
# F1: 0.433
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5852.0          152.0
# True YES         441.0          148.0
#
# F1: 0.333
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6220.0          100.0
# True YES         335.0          109.0
#
# F1: 0.334
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1229.0           33.0
# True YES          97.0           37.0
#
# F1: 0.363
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6936.0          206.0
# True YES         515.0          153.0
#
# F1: 0.298
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1036.0           41.0
# True YES         131.0           50.0
#
# F1: 0.368
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5024.0          169.0
# True YES         339.0          106.0
#
# F1: 0.294
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4414.0          212.0
# True YES         625.0          239.0
#
# F1: 0.363
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3734.0          107.0
# True YES         333.0           94.0
#
# F1: 0.299
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5144.0          165.0
# True YES         431.0          136.0
#
# F1: 0.313
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.241571
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2725.0          123.0
# True YES         364.0          120.0
#
# F1: 0.330
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          323.0           16.0
# True YES          57.0           24.0
#
# F1: 0.397
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.30
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5887.0          117.0
# True YES         481.0          108.0
#
# F1: 0.265
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6250.0           70.0
# True YES         363.0           81.0
#
# F1: 0.272
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1230.0           32.0
# True YES         107.0           27.0
#
# F1: 0.280
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6962.0          180.0
# True YES         523.0          145.0
#
# F1: 0.292
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1043.0           34.0
# True YES         140.0           41.0
#
# F1: 0.320
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5067.0          126.0
# True YES         362.0           83.0
#
# F1: 0.254
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4493.0          133.0
# True YES         674.0          190.0
#
# F1: 0.320
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3752.0           89.0
# True YES         358.0           69.0
#
# F1: 0.236
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5186.0          123.0
# True YES         449.0          118.0
#
# F1: 0.292
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.219574
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2769.0           79.0
# True YES         388.0           96.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          326.0           13.0
# True YES          55.0           26.0
#
# F1: 0.433
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5866.0          138.0
# True YES         449.0          140.0
#
# F1: 0.323
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6230.0           90.0
# True YES         334.0          110.0
#
# F1: 0.342
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1233.0           29.0
# True YES          99.0           35.0
#
# F1: 0.354
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6949.0          193.0
# True YES         516.0          152.0
#
# F1: 0.300
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1035.0           42.0
# True YES         132.0           49.0
#
# F1: 0.360
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5033.0          160.0
# True YES         334.0          111.0
#
# F1: 0.310
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4442.0          184.0
# True YES         642.0          222.0
#
# F1: 0.350
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3740.0          101.0
# True YES         331.0           96.0
#
# F1: 0.308
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5153.0          156.0
# True YES         432.0          135.0
#
# F1: 0.315
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.318307
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2740.0          108.0
# True YES         368.0          116.0
#
# F1: 0.328
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          328.0           11.0
# True YES          64.0           17.0
#
# F1: 0.312
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5905.0           99.0
# True YES         499.0           90.0
#
# F1: 0.231
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.15
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6264.0           56.0
# True YES         379.0           65.0
#
# F1: 0.230
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.15
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1236.0           26.0
# True YES         110.0           24.0
#
# F1: 0.261
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         7010.0          132.0
# True YES         562.0          106.0
#
# F1: 0.234
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1047.0           30.0
# True YES         148.0           33.0
#
# F1: 0.270
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5087.0          106.0
# True YES         375.0           70.0
#
# F1: 0.225
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.16
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4519.0          107.0
# True YES         701.0          163.0
#
# F1: 0.287
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3777.0           64.0
# True YES         371.0           56.0
#
# F1: 0.205
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.13
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5212.0           97.0
# True YES         463.0          104.0
#
# F1: 0.271
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.18
#
# Optimization terminated successfully.
#          Current function value: 0.207615
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2784.0           64.0
# True YES         400.0           84.0
#
# F1: 0.266
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.17
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          324.0           15.0
# True YES          58.0           23.0
#
# F1: 0.387
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5822.0          182.0
# True YES         428.0          161.0
#
# F1: 0.345
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6217.0          103.0
# True YES         342.0          102.0
#
# F1: 0.314
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1202.0           60.0
# True YES          91.0           43.0
#
# F1: 0.363
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6864.0          278.0
# True YES         493.0          175.0
#
# F1: 0.312
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.26
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1014.0           63.0
# True YES         130.0           51.0
#
# F1: 0.346
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4979.0          214.0
# True YES         322.0          123.0
#
# F1: 0.315
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4462.0          164.0
# True YES         655.0          209.0
#
# F1: 0.338
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3727.0          114.0
# True YES         343.0           84.0
#
# F1: 0.269
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5134.0          175.0
# True YES         402.0          165.0
#
# F1: 0.364
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.353802
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2757.0           91.0
# True YES         370.0          114.0
#
# F1: 0.331
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          324.0           15.0
# True YES          57.0           24.0
#
# F1: 0.400
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.30
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5843.0          161.0
# True YES         439.0          150.0
#
# F1: 0.333
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6235.0           85.0
# True YES         354.0           90.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1217.0           45.0
# True YES          96.0           38.0
#
# F1: 0.350
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.28
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6906.0          236.0
# True YES         505.0          163.0
#
# F1: 0.306
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1018.0           59.0
# True YES         132.0           49.0
#
# F1: 0.339
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4997.0          196.0
# True YES         338.0          107.0
#
# F1: 0.286
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4466.0          160.0
# True YES         663.0          201.0
#
# F1: 0.328
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3742.0           99.0
# True YES         343.0           84.0
#
# F1: 0.275
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5141.0          168.0
# True YES         414.0          153.0
#
# F1: 0.345
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.247253
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2767.0           81.0
# True YES         379.0          105.0
#
# F1: 0.313
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO          328.0           11.0
# True YES          56.0           25.0
#
# F1: 0.427
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5855.0          149.0
# True YES         450.0          139.0
#
# F1: 0.317
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6233.0           87.0
# True YES         353.0           91.0
#
# F1: 0.293
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1228.0           34.0
# True YES         101.0           33.0
#
# F1: 0.328
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.25
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         6963.0          179.0
# True YES         529.0          139.0
#
# F1: 0.282
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.21
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         1034.0           43.0
# True YES         139.0           42.0
#
# F1: 0.316
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5045.0          148.0
# True YES         346.0           99.0
#
# F1: 0.286
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.22
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         4459.0          167.0
# True YES         653.0          211.0
#
# F1: 0.340
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         3753.0           88.0
# True YES         344.0           83.0
#
# F1: 0.278
#
# Accuracy on class 0: 0.98
# Accuracy on class 1: 0.19
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         5157.0          152.0
# True YES         433.0          134.0
#
# F1: 0.314
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.24
#
# Optimization terminated successfully.
#          Current function value: 0.240419
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO         2759.0           89.0
# True YES         387.0           97.0
#
# F1: 0.290
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.20
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO          321.0           18.0
# True YES          56.0           25.0
#
# F1: 0.403
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5753.0          251.0
# True YES         400.0          189.0
#
# F1: 0.367
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6149.0          171.0
# True YES         314.0          130.0
#
# F1: 0.349
#
# Accuracy on class 0: 0.97
# Accuracy on class 1: 0.29
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1184.0           78.0
# True YES          89.0           45.0
#
# F1: 0.350
#
# Accuracy on class 0: 0.94
# Accuracy on class 1: 0.34
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         6773.0          369.0
# True YES         458.0          210.0
#
# F1: 0.337
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         1005.0           72.0
# True YES         124.0           57.0
#
# F1: 0.368
#
# Accuracy on class 0: 0.93
# Accuracy on class 1: 0.31
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4909.0          284.0
# True YES         303.0          142.0
#
# F1: 0.326
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.32
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         4416.0          210.0
# True YES         628.0          236.0
#
# F1: 0.360
#
# Accuracy on class 0: 0.95
# Accuracy on class 1: 0.27
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         3693.0          148.0
# True YES         329.0           98.0
#
# F1: 0.291
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.23
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         5087.0          222.0
# True YES         380.0          187.0
#
# F1: 0.383
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.33
#
# Optimization terminated successfully.
#          Current function value: 0.335785
#          Iterations 7
#           Predicted NO  Predicted YES
# True NO         2736.0          112.0
# True YES         355.0          129.0
#
# F1: 0.356
#
# Accuracy on class 0: 0.96
# Accuracy on class 1: 0.27

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.heatmap(acc_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('Accuracy')

plt.subplot(122)
sns.heatmap(F1_matrix)
plt.xticks(np.arange(11)+0.5,mice,rotation='vertical')
plt.yticks(np.arange(11)+0.5,mice[::-1],rotation='horizontal')
plt.xlabel('Training Mouse')
plt.ylabel('Testing Mouse')
plt.title('F1')

# %%
data_80.head(2)
# Out:
#    Condition Mouse ID   Session ID  Block Trial  Port Streak  Reward Streak  \
# 0        0.8       K1  11212016_K1         11.0          1.0            1.0
# 1        0.8       K1  11212016_K1         12.0          2.0            2.0
#
#    10_Port  10_Reward  10_ITI  10_trialDuration   ...    2_trialDuration  \
# 0     -1.0        1.0   1.993             0.727   ...              0.524
# 1     -1.0        1.0   1.729             0.894   ...              0.573
#
#    1_Port  1_Reward  1_ITI  1_trialDuration  0_ITI  Decision  Switch  \
# 0    -1.0       1.0  1.303            0.573  1.952       0.0     0.0
# 1    -1.0       1.0  1.952            0.445  2.681       0.0     0.0
#
#    Higher p port  Reward
# 0            1.0     1.0
# 1            1.0     1.0
#
# [2 rows x 51 columns]

# %%
u_switch = np.zeros(len(mice))
u_acc = np.zeros(len(mice))

for i,mouse in enumerate(mice):
    u_switch[i] = data_80[data_80['Mouse ID']== mouse]['Switch'].mean()
    u_acc[i] = data_80[data_80['Mouse ID']== mouse]['Higher p port'].mean()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates anti-correlate with accuracy on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as test mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Testing accuracy vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean accuracy when used as train mouse')
plt.ylim(0.75,1)
plt.xlim(0,0.22)
plt.title('Training accuracy vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Higher switch rates correlate with F1 score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_switch[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean switch rate')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('Better behavior correlates with accuracy score on test mice',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing Acc vs mean p(high p port)')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],acc_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('mean p(high p port)')
plt.ylabel('mean acc when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training acc vs mean p(high p port)')

plt.tight_layout()

# %%
colors = sns.color_palette('hls',n_colors=len(mice))
plt.figure(figsize=(12,5))
plt.suptitle('p(high p port) vs F1 score',fontsize=20,x=0.5,y=1.1)
plt.subplot(121)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[i,:].mean(),label=mouse,c=colors[i],s=50)
#plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as test mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Testing F1 vs mean switch rate')


plt.subplot(122)
for i,mouse in enumerate(mice):
    plt.scatter(u_acc[i],F1_matrix[:,i].mean(),label=mouse,c=colors[i],s=50)
plt.legend(bbox_to_anchor=(1.3,1))
plt.xlabel('p(high p port)')
plt.ylabel('mean F1 when used as train mouse')
#plt.ylim(0.75,1)
#plt.xlim(0,0.22)
plt.title('Training F1 vs mean switch rate')

plt.tight_layout()

# %% [markdown]
# # Trying interaction terms

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias=True)

# %%
def logreg_and_eval_withports_and_interactions(data,num_rewards=10,num_ports=1,test_data=False):
    '''
    Perform Logistic Regression on a pandas dataframe of trials (from feature matrix) with interactions
    
    Inputs:
        - data: pandas dataframe of trials (from feature matrix)
    Outputs:
        - logreg: trained logistic regression model (from sklearn)
        - stats:  pandas dataframe with F1, pseudo-R2, and BIC scores from model
        - coeffs: beta coefficients from logreg
    
    '''
    
    from statsmodels.discrete.discrete_model import Logit
    
    port_features = []
    reward_features = []

    #change right port to -1 instead of 0
    for col in data:
        if '_Port' in col:
            data.loc[data[col] == 0,col] = -1
            port_features.append(col)
        elif '_Reward' in col:
            reward_features.append(col)

    #create new feature matrix
    d = data.copy()
    for i in range(len(port_features)):
        d[reward_features[i]] = d[reward_features[i]].values*d[port_features[i]].values
    
    
    #determine the features
    features = reward_features.copy()
    if num_rewards == 0:
        features = port_features[-1*num_ports:]
    elif num_ports == 0:
        features = features[-1*num_rewards:] #only take the num of rewards specificied in the function
    else:
        features = features[-1*num_rewards:]
        features = np.append(features,port_features[-1*num_ports:])
    
    print(features)
    features = np.append(features,'Decision') #finally append the decision so we can take it to predict later
    
    
    
    #final version of data
    d = d[features].copy() #this now just has the features we want and the decision we want to predict
    
    #do the same thing for the test data if it exists!
    if test_data is not False:
        for col in test_data:
            if '_Port' in col:
                test_data.loc[test_data[col] == 0,col] = -1

        #create new feature matrix
        data_test_new = test_data.copy()
        for i in range(len(port_features)):
            data_test_new[reward_features[i]] = test_data[reward_features[i]].values*test_data[port_features[i]].values
        
        d_test = data_test_new[features].copy()
    
    
        #set training and testing sets now
        x_train = d.iloc[:,:-1].values
        y_train = d.iloc[:,-1].values
        x_test = d_test.iloc[:,:-1].values
        y_test = d_test.iloc[:,-1].values
        
        prev_port_test = test_data['1_Port'].values
        prev_port_test[prev_port_test==-1] = 0
    
    #if there is no test data, then split up the data into training and testing
    else:
        #extract features and decisions
        x = d.iloc[:,:-1].values
        y = d.iloc[:,-1].values

        #split into training and testing
        n_trials = x.shape[0]
        shuf_inds = np.random.permutation(n_trials)
        split_ind = int(n_trials*0.7)

        x_train = x[shuf_inds[:split_ind],:]
        y_train = y[shuf_inds[:split_ind]]

        x_test = x[shuf_inds[split_ind:],:]
        y_test = y[shuf_inds[split_ind:]]
        
        #extract previous port decision for test set
        #these will be used to calculate switches on the test predictions
        prev_port_test = data['1_Port'].values[shuf_inds[split_ind:]]
        prev_port_test[prev_port_test==-1] = 0
    
    '''
    Modeling
    '''
    
    #create interaction terms
    poly = PolynomialFeatures(degree=2,interaction_only=True,include_bias=True)
    x_train = poly.fit_transform(x_train)
    x_test = poly.fit_transform(x_test)
    print('x_train shape: %.0f' % x_train.shape[1])
    
    
    #fit logistic regression
    logreg = sklearn.linear_model.LogisticRegressionCV()
    logreg.fit(x_train,y_train)
    
    #predict on testing set
    y_predict = logreg.predict(x_test)
    y_predict_proba = logreg.predict_proba(x_test)
    
    #model accuracy
    score = logreg.score(x_test,y_test)
    
    #calculating pseudo-R2 and BIC from statsmodel OLS
    model = Logit(y_train,x_train)
    rslt  = model.fit()

    #switches
    y_test_switch = np.abs(y_test - prev_port_test)
    y_predict_switch = np.abs(y_predict - prev_port_test)
    acc_pos,acc_neg,F1=sf.score_both_and_confuse(y_predict_switch,y_test_switch,confusion=False,disp=True)
    
    #extract coefficients
    coefs = logreg.coef_ #retrieve coefs
    coefs = np.append(coefs[0],logreg.intercept_) #add bias coef
    
    #create stats database to return
    d_ = {'pseudo-R2':rslt.prsquared,'stay':acc_pos,'switch':acc_neg,'Accuracy':score,'BIC':rslt.bic,'negative loglikelihood':-1*rslt.llf}
    stats = pd.DataFrame(data=d_,index=[0])
    features = features[:-1]
    features = np.append(features,'Bias')
    
    #coefs = pd.DataFrame(data=coefs.reshape(1,-1),columns=poly.get_feature_names())
    return logreg,stats

# %%
model,stats_curr = logreg_and_eval_withports_and_interactions(data_80,num_rewards = 5)
# Out:
# ['5_Reward' '4_Reward' '3_Reward' '2_Reward' '1_Reward' '1_Port']
# x_train shape: 22
# Optimization terminated successfully.
#          Current function value: 0.246633
#          Iterations 8
#           Predicted NO  Predicted YES
# True NO        13045.0          119.0
# True YES        1340.0          150.0
#
# F1: 0.171
#
# Accuracy on class 0: 0.99
# Accuracy on class 1: 0.10

# %%
model.coef_.shape[1]
# Out:
# 22

# %%
plt.scatter(np.arange(model.coef_.shape[1]),model.coef_)
