# %%
import sys
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sys
import os
import behavior_database

# %% [markdown]
# ## load in database

# %%
record_df = pd.read_csv('/Users/shayneufeld/GitHub/mouse_bandit/session_record.csv',index_col=0)

# %%
record_df.shape
# Out:
# (692, 16)

# %% [markdown]
# ## Add single day (multi mice)

# %%
DAY = '03172017'
ROOT = '/Users/shayneufeld/Dropbox/Shay_BehaviorFiles/BehaviorData/datesfirst'
root_day = os.path.join(ROOT,DAY)

mouse_folders = os.listdir(root_day)

for mouse in mouse_folders:
    if not mouse[0] == '.':
        curr_dir = os.path.join(root_day,mouse)

        record_df = behavior_database.add_session(curr_dir,record_df)

# %%
mouse_folders
# Out:
# ['K1', 'K13', 'K7', 'K9', 'Q43', 'Q45']

# %%
record_df.tail(50)
# Out:
#        Session ID Mouse ID                 Date  Phase  Left Reward Prob  \
# 642  01262017_q45      q45  2017-01-26 00:00:00    2.0               0.9
# 643  01272017_q45      q45  2017-01-27 00:00:00    2.0               0.9
# 644  01302017_q45      q45  2017-01-30 00:00:00    2.0               0.1
# 645  01312017_q45      q45  2017-01-31 00:00:00    2.0               0.1
# 646  02012017_q45      q45  2017-02-01 00:00:00    2.0               0.1
# 647  02022017_q45      q45  2017-02-02 00:00:00    2.0               0.1
# 648  02202017_q45      q45  2017-02-20 00:00:00    2.0               0.1
# 649  02212017_q45      q45  2017-02-21 00:00:00    2.0               0.9
# 650  02222017_q45      q45  2017-02-22 00:00:00    2.0               0.9
# 651  02232017_q45      q45  2017-02-23 00:00:00    2.0               0.9
# 652  02242017_q45      q45  2017-02-24 00:00:00    2.0               0.9
# 653  03012017_q45      q45  2017-03-01 00:00:00    2.0               0.1
# 654  03022017_q45      q45  2017-03-02 00:00:00    2.0               0.1
# 655  03032017_q45      q45  2017-03-03 00:00:00    2.0               0.1
# 656   03082017_k1       K1  2017-03-08 00:00:00    2.0               0.1
# 657  03082017_k13      K13  2017-03-08 00:00:00    2.0               0.9
# 658   03082017_k7       K7  2017-03-08 00:00:00    2.0               0.1
# 659   03082017_k9       K9  2017-03-08 00:00:00    2.0               0.1
# 660  03082017_Q43      Q43  2017-03-08 00:00:00    2.0               0.9
# 661  03082017_Q45      Q45  2017-03-08 00:00:00    2.0               0.1
# 662   03092017_K1       K1  2017-03-09 00:00:00    2.0               0.1
# 663  03092017_K13      K13  2017-03-09 00:00:00    2.0               0.9
# 664   03092017_K7       K7  2017-03-09 00:00:00    2.0               0.9
# 665   03092017_K9       K9  2017-03-09 00:00:00    2.0               0.9
# 666  03092017_Q43      Q43  2017-03-09 00:00:00    2.0               0.9
# 667  03092017_Q45      Q45  2017-03-09 00:00:00    2.0               0.9
# 668   03132017_K1       K1  2017-03-13 00:00:00    2.0               0.9
# 669  03132017_K13      K13  2017-03-13 00:00:00    2.0               0.2
# 670   03132017_K7       K7  2017-03-13 00:00:00    2.0               0.8
# 671   03132017_K9       K9  2017-03-13 00:00:00    2.0               0.9
# 645                       1.0                    35.0                     35.0
# 646                       1.0                    35.0                     35.0
# 647                       1.0                    35.0                     35.0
# 648                       1.0                    35.0                     35.0
# 649                       1.0                    35.0                     35.0
# 650                       1.0                    35.0                     35.0
# 651                       1.0                    35.0                     35.0
# 652                       1.0                    35.0                     35.0
# 653                       1.0                    35.0                     35.0
# 654                       1.0                    35.0                     35.0
# 655                       1.0                    35.0                     35.0
# 656                       1.0                    35.0                     35.0
# 657                       1.0                    35.0                     35.0
# 658                       1.0                    35.0                     35.0
# 659                       1.0                    35.0                     35.0
# 660                       1.0                    35.0                     35.0
# 661                       1.0                    35.0                     35.0
# 662                       1.0                    35.0                     35.0
# 663                       1.0                    35.0                     35.0
# 664                       1.0                    35.0                     35.0
# 665                       1.0                    35.0                     35.0
# 666                       1.0                    35.0                     35.0
# 667                       1.0                    35.0                     35.0
# 668                       1.0                    35.0                     35.0
# 669                       1.0                    35.0                     35.0
# 670                       1.0                    35.0                     35.0
# 671                       1.0                    35.0                     35.0
# 672                       1.0                    35.0                     35.0
# 673                       1.0                    35.0                     35.0
# 674                       1.0                    35.0                     35.0
# 675                       1.0                    35.0                     35.0
# 676                       1.0                    35.0                     35.0
# 677                       1.0                    35.0                     35.0
# 678                       1.0                    35.0                     35.0
# 679                       1.0                    35.0                     35.0
# 680                       1.0                    35.0                     35.0
# 681                       1.0                    35.0                     35.0
# 682                       1.0                    35.0                     35.0
# 683                       1.0                    35.0                     35.0
# 684                       1.0                    35.0                     35.0
# 685                       1.0                    35.0                     35.0
# 686                       1.0                    35.0                     35.0
# 687                       1.0                    35.0                     35.0
# 688                       1.0                    35.0                     35.0
# 689                       1.0                    35.0                     35.0
# 690                       1.0                    35.0                     35.0
# 691                       1.0                    35.0                     35.0

# %%
date = '10032016'
date_str = str(date)

pd.to_datetime(date_str,format='%m%d%Y')
# Out:
# Timestamp('2016-10-03 00:00:00')

# %%
record_df.loc[659,'Mouse ID'] = 'K9'

# %%
record_df[record_df['Mouse ID'] == 'k7']
# Out:
# Empty DataFrame
# Columns: [Session ID, Mouse ID, Date, Phase, Left Reward Prob, Right Reward Prob, Block Range Min, Block Range Max, No. Trials, No. Blocks, No. Rewards, p(high Port), Decision Window Duration, Min Inter-trial-interval, Left Solenoid Duration, Right Solenoid Duration]
# Index: []

# %%
record_df.to_csv(path_or_buf='/Users/shayneufeld/GitHub/mouse_bandit/session_record.csv')

# %% [markdown]
# # Need to change dates to actual date objects
#
# - convert all to strings
# - check if string is 8 characters long. if its 7, add a 0 at the beginning
# - convert to datetime objects

# %%
# convert to strings

dates = record_df['Date'].values
dates_str = []
datetimes = []

for date in dates:
    date_str = np.str(date)
    
    if (len(date_str) == 7):
        date_str = '0' + date_str
    
    dates_str.append(date_str)
    
    datetimes.append(pd.to_datetime(date_str,format='%m%d%Y'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     408             try:
# --> 409                 values, tz = tslib.datetime_to_datetime64(arg)
#     410                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/tslib.pyx in pandas.tslib.datetime_to_datetime64 (pandas/tslib.c:29768)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-2f90fb35f3de> in <module>()
#      13     dates_str.append(date_str)
#      14
# ---> 15     datetimes.append(pd.to_datetime(date_str,format='%m%d%Y'))
#
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/util/decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/tseries/tools.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, coerce, unit, infer_datetime_format)
#     289                         yearfirst=yearfirst,
#     290                         utc=utc, box=box, format=format, exact=exact,
# --> 291                         unit=unit, infer_datetime_format=infer_datetime_format)
#     292
#     293
#
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/tseries/tools.py in _to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, freq, infer_datetime_format)
#     427         return _convert_listlike(arg, box, format)
#     428
# --> 429     return _convert_listlike(np.array([arg]), box, format)[0]
#     430
#     431 # mappings for assembling units
#
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     410                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     411             except (ValueError, TypeError):
# --> 412                 raise e
#     413
#     414     if arg is None:
#
# //anaconda/envs/CaGRIN/lib/python3.5/site-packages/pandas/tseries/tools.py in _convert_listlike(arg, box, format, name)
#     374                     try:
#     375                         result = tslib.array_strptime(
# --> 376                             arg, format, exact=exact, errors=errors)
#     377                     except tslib.OutOfBoundsDatetime:
#     378                         if errors == 'raise':
#
# pandas/tslib.pyx in pandas.tslib.array_strptime (pandas/tslib.c:57701)()
#
# ValueError: time data '2017-03-15 00:00:00' does not match format '%m%d%Y' (match)

# %%
len(datetimes)
# Out:
# 680

# %%
datetimes[0]
# Out:
# Timestamp('2016-11-01 00:00:00')

# %%
record_df_copy.iloc[0]['Date']
# Out:
# '11012016'

# %%
record_df_copy.loc[:679].shape
# Out:
# (680, 16)

# %%
record_df_copy = record_df.copy()
record_df_copy.loc[:679,'Date'] = datetimes;

# %%
record_df_copy.head(5)
# Out:
#     Session ID Mouse ID                 Date  Phase  Left Reward Prob  \
# 0  11012016_K1       K1  2016-11-01 00:00:00    1.0               1.0
# 1  11022016_K1       K1  2016-11-02 00:00:00    1.0               1.0
# 2  11032016_K1       K1  2016-11-03 00:00:00    1.0               1.0
# 3  11042016_K1       K1  2016-11-04 00:00:00    2.0               0.1
# 4  11082016_K1       K1  2016-11-08 00:00:00    1.0               1.0
#
#    Right Reward Prob  Block Range Min  Block Range Max  No. Trials  \
# 0                1.0           1000.0           1000.0         8.0
# 1                1.0           1000.0           1000.0        85.0
# 2                1.0           1000.0           1000.0       104.0
# 3                0.9             50.0             50.0        70.0
# 4                1.0            500.0            500.0       118.0
#
#    No. Blocks  No. Rewards  p(high Port)  Decision Window Duration  \
# 0         0.0          8.0          0.00                      10.0
# 1         0.0         85.0          0.00                      10.0
# 2         0.0        104.0          0.00                       3.0
# 3         1.0         50.0          0.83                       2.0
# 4         0.0        118.0          0.00                       5.0
#
#    Min Inter-trial-interval  Left Solenoid Duration  Right Solenoid Duration
# 0                       0.5                    35.0                     35.0
# 1                       0.5                    35.0                     35.0
# 2                       1.0                    35.0                     35.0
# 3                       1.0                    35.0                     35.0
# 4                       1.0                    60.0                     60.0

# %%
record_df.head(5)
# Out:
#     Session ID Mouse ID      Date  Phase  Left Reward Prob  Right Reward Prob  \
# 0  11012016_K1       K1  11012016    1.0               1.0                1.0
# 1  11022016_K1       K1  11022016    1.0               1.0                1.0
# 2  11032016_K1       K1  11032016    1.0               1.0                1.0
# 3  11042016_K1       K1  11042016    2.0               0.1                0.9
# 4  11082016_K1       K1  11082016    1.0               1.0                1.0
#
#    Block Range Min  Block Range Max  No. Trials  No. Blocks  No. Rewards  \
# 0           1000.0           1000.0         8.0         0.0          8.0
# 1           1000.0           1000.0        85.0         0.0         85.0
# 2           1000.0           1000.0       104.0         0.0        104.0
# 3             50.0             50.0        70.0         1.0         50.0
# 4            500.0            500.0       118.0         0.0        118.0
#
#    p(high Port)  Decision Window Duration  Min Inter-trial-interval  \
# 0          0.00                      10.0                       0.5
# 1          0.00                      10.0                       0.5
# 2          0.00                       3.0                       1.0
# 3          0.83                       2.0                       1.0
# 4          0.00                       5.0                       1.0
#
#    Left Solenoid Duration  Right Solenoid Duration
# 0                    35.0                     35.0
# 1                    35.0                     35.0
# 2                    35.0                     35.0
# 3                    35.0                     35.0
# 4                    60.0                     60.0

# %%
record_df = record_df_copy.copy()

# %%
record_df.head(20)
# Out:
#      Session ID Mouse ID                 Date  Phase  Left Reward Prob  \
# 0   11012016_K1       K1  2016-11-01 00:00:00    1.0               1.0
# 1   11022016_K1       K1  2016-11-02 00:00:00    1.0               1.0
# 2   11032016_K1       K1  2016-11-03 00:00:00    1.0               1.0
# 3   11042016_K1       K1  2016-11-04 00:00:00    2.0               0.1
# 4   11082016_K1       K1  2016-11-08 00:00:00    1.0               1.0
# 5   11092016_K1       K1  2016-11-09 00:00:00    1.0               1.0
# 6   11102016_K1       K1  2016-11-10 00:00:00    2.0               0.0
# 7   11112016_K1       K1  2016-11-11 00:00:00    2.0               0.0
# 8   11142016_K1       K1  2016-11-14 00:00:00    2.0               0.1
# 9   11152016_K1       K1  2016-11-15 00:00:00    2.0               0.1
# 10  11162016_K1       K1  2016-11-16 00:00:00    2.0               0.1
# 11  11172016_K1       K1  2016-11-17 00:00:00    2.0               0.2
# 12  11182016_K1       K1  2016-11-18 00:00:00    2.0               0.8
# 13  11212016_K1       K1  2016-11-21 00:00:00    2.0               0.2
# 14  11222016_K1       K1  2016-11-22 00:00:00    2.0               0.8
# 15  11292016_K1       K1  2016-11-29 00:00:00    2.0               0.1
# 16  11302016_K1       K1  2016-11-30 00:00:00    2.0               0.8
# 17  12012016_K1       K1  2016-12-01 00:00:00    2.0               0.2
# 18  12022016_K1       K1  2016-12-02 00:00:00    2.0               0.2
# 19  12052016_K1       K1  2016-12-05 00:00:00    2.0               0.2
#
#     Right Reward Prob  Block Range Min  Block Range Max  No. Trials  \
# 0                 1.0           1000.0           1000.0         8.0
# 1                 1.0           1000.0           1000.0        85.0
# 2                 1.0           1000.0           1000.0       104.0
# 3                 0.9             50.0             50.0        70.0
# 4                 1.0            500.0            500.0       118.0
# 5                 1.0            500.0            500.0       133.0
# 6                 1.0             30.0             30.0       213.0
# 7                 1.0             50.0             50.0       315.0
# 8                 0.9             50.0             50.0       415.0
# 9                 0.9             50.0             50.0       315.0
# 10                0.9             50.0             50.0       217.0
# 11                0.8             30.0             40.0       198.0
# 12                0.2             20.0             40.0       213.0
# 13                0.8             50.0             50.0       349.0
# 14                0.2             20.0             40.0       281.0
# 15                0.9             50.0             50.0       399.0
# 16                0.2             10.0             40.0       470.0
# 17                0.8             50.0             50.0        91.0
# 18                0.8             10.0             40.0       194.0
# 19                0.8             10.0             40.0       364.0
#
#     No. Blocks  No. Rewards  p(high Port)  Decision Window Duration  \
# 0          0.0          8.0          0.00                      10.0
# 1          0.0         85.0          0.00                      10.0
# 2          0.0        104.0          0.00                       3.0
# 3          1.0         50.0          0.83                       2.0
# 4          0.0        118.0          0.00                       5.0
# 5          0.0        133.0          0.00                       5.0
# 6          4.0        134.0          0.63                       5.0
# 7          5.0        258.0          0.82                       2.0
# 8          5.0        284.0          0.72                       2.0
# 9          4.0        228.0          0.77                       2.0
# 10         3.0        169.0          0.85                       2.0
# 11         3.0        131.0          0.80                       2.0
# 12         4.0        128.0          0.65                       2.0
# 13         4.0        219.0          0.74                       2.0
# 14         6.0        200.0          0.84                       2.0
# 15         6.0        305.0          0.82                       2.0
# 16        10.0        289.0          0.68                       2.0
# 17         1.0         54.0          0.77                       2.0
# 18         5.0        127.0          0.75                       2.0
# 19         8.0        238.0          0.75                       2.0
#
#     Min Inter-trial-interval  Left Solenoid Duration  Right Solenoid Duration
# 0                        0.5                    35.0                     35.0
# 1                        0.5                    35.0                     35.0
# 2                        1.0                    35.0                     35.0
# 3                        1.0                    35.0                     35.0
# 4                        1.0                    60.0                     60.0
# 5                        1.0                    60.0                     60.0
# 6                        1.0                    35.0                     35.0
# 7                        1.0                    35.0                     35.0
# 8                        1.0                    35.0                     35.0
# 9                        1.0                    35.0                     35.0
# 10                       1.0                    35.0                     35.0
# 11                       1.0                    35.0                     35.0
# 12                       1.0                    35.0                     35.0
# 13                       1.0                    35.0                     35.0
# 14                       1.0                    35.0                     35.0
# 15                       1.0                    35.0                     35.0
# 16                       1.0                    35.0                     35.0
# 17                       1.0                    35.0                     35.0
# 18                       1.0                    35.0                     35.0
# 19                       1.0                    35.0                     35.0
