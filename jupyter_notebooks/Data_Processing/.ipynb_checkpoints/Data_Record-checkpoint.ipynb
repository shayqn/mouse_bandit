# %%
import sys
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit/data_preprocessing_code')
sys.path.append('/Users/shayneufeld/GitHub/mouse_bandit')
import support_functions as sf
import numpy as np
import pandas as pd
import scipy as sp
import bandit_preprocessing as bp
import sys
import os

# %%
names = [
    'Session ID',
    'Mouse ID',
    'Date',
    'Phase',
    'Left Reward Prob',
    'Right Reward Prob',
    'Block Range Min',
    'Block Range Max',
    'No. Trials',
    'No. Blocks',
    'No. Rewards',
    'p(high Port)',
    'Decision Window Duration',
    'Min Inter-trial-interval',
    'Left Solenoid Duration',
    'Right Solenoid Duration'
]

# %%
df = pd.DataFrame(data=None,columns=names,index=None)

# %%
'''
load in trial data
'''
columns = ['Elapsed Time (s)','Since last trial (s)','Trial Duration (s)','Port Poked','Right Reward Prob','Left Reward Prob','Reward Given']

root_dir = '/Users/shayneufeld/GitHub/mouse_bandit/data/test'

trial_df = []
mouse_ids = []
session_ids = []

for file in os.listdir(root_dir):
    if not file[0] == '.':
        file_name = os.path.join(root_dir,file)
        
        if 'trials.csv' in file:
            print('trials')
            trials = pd.read_csv(file_name,names=columns)
            
        elif 'parameters.csv' in file:
            print('params')
            params = pd.read_csv(file_name)
# Out:
# params
# trials

# %%
high_p_port = np.zeros(trials.shape[0])

for row in trials.iterrows():
    i = row[0]
    current_trial = row[1]
    
    if ((current_trial['Right Reward Prob'] > current_trial['Left Reward Prob']) & (current_trial['Port Poked'] == 1)):
        high_p_port[i] = 1
    elif ((current_trial['Right Reward Prob'] < current_trial['Left Reward Prob']) & (current_trial['Port Poked'] == 2)):
        high_p_port[i] = 1

# %%
if params['centerPokeTrigger'].values == 0:
    phase = 0
elif (params['leftRewardProb'].values == params['rightRewardProb'].values):
    phase = 1
else:
    phase = 2

# %%
record = {
    'Session ID':file[:file.index('_',9)],
    'Mouse ID': file[9:file.index('_',9)],
    'Date': file[:8],
    'Phase': phase,
    'Left Reward Prob': params['leftRewardProb'].values,
    'Right Reward Prob': params['rightRewardProb'].values,
    'Block Range Min': params['blockRangeMin'],
    'Block Range Max': params['blockRangeMax'],
    'No. Trials': trials.shape[0],
    'No. Blocks': np.sum(np.diff(trials['Right Reward Prob'].values) != 0),
    'No. Rewards': np.sum(trials['Reward Given']),
    'p(high Port)': np.round(high_p_port.mean(),decimals=2),
    'Decision Window Duration': params['centerPokeRewardWindow'],
    'Min Inter-trial-interval': params['minInterTrialInterval'],
    'Left Solenoid Duration': params['rewardDurationLeft'],
    'Right Solenoid Duration': params['rewardDurationRight']  
         }

# %%
df.append(pd.DataFrame(data=record,columns=names))
# Out:
#         Session ID Mouse ID      Date  Phase  Left Reward Prob  \
# 0  07262016_dumble   dumble  07262016    2.0               0.2
#
#    Right Reward Prob  Block Range Min  Block Range Max  No. Trials  \
# 0                0.8             50.0             50.0       605.0
#
#    No. Blocks  No. Rewards  p(high Port)  Decision Window Duration  \
# 0         8.0        442.0          0.86                       2.0
#
#    Min Inter-trial-interval  Left Solenoid Duration  Right Solenoid Duration
# 0                       1.0                    45.0                     40.0

# %% [markdown]
# # Test database function

# %%
df = pd.DataFrame(data=None,columns=names,index=None)
df
# Out:
# Empty DataFrame
# Columns: [Session ID, Mouse ID, Date, Phase, Left Reward Prob, Right Reward Prob, Block Range Min, Block Range Max, No. Trials, No. Blocks, No. Rewards, p(high Port), Decision Window Duration, Min Inter-trial-interval, Left Solenoid Duration, Right Solenoid Duration]
# Index: []

# %%
ROOT_DIR = '/Users/shayneufeld/Dropbox/Shay_BehaviorFiles/BehaviorData_supermice/K1'
record_df = df

output_df = record_df.copy()

names = [
    'Session ID',
    'Mouse ID',
    'Date',
    'Phase',
    'Left Reward Prob',
    'Right Reward Prob',
    'Block Range Min',
    'Block Range Max',
    'No. Trials',
    'No. Blocks',
    'No. Rewards',
    'p(high Port)',
    'Decision Window Duration',
    'Min Inter-trial-interval',
    'Left Solenoid Duration',
    'Right Solenoid Duration'
]

for curr_dir in os.listdir(ROOT_DIR):

    '''
    load in trial data
    '''
    columns = ['Elapsed Time (s)','Since last trial (s)','Trial Duration (s)','Port Poked','Right Reward Prob','Left Reward Prob','Reward Given']

    try:
        for file in os.listdir(os.path.join(ROOT_DIR,curr_dir)):
            if not file[0] == '.':
                file_name = os.path.join(ROOT_DIR,curr_dir,file)

                if 'trials.csv' in file:
                    trials = pd.read_csv(file_name,names=columns)
                    session_id = file[:file.index('_',9)]

                elif 'parameters.csv' in file:
                    params = pd.read_csv(file_name)

    
        high_p_port = np.zeros(trials.shape[0])

        for row in trials.iterrows():
            i = row[0]
            current_trial = row[1]

            if ((current_trial['Right Reward Prob'] > current_trial['Left Reward Prob']) & (current_trial['Port Poked'] == 1)):
                high_p_port[i] = 1
            elif ((current_trial['Right Reward Prob'] < current_trial['Left Reward Prob']) & (current_trial['Port Poked'] == 2)):
                high_p_port[i] = 1

        if params['centerPokeTrigger'].values == 0:
            phase = 0
        elif (params['leftRewardProb'].values == params['rightRewardProb'].values):
            phase = 1
        else:
            phase = 2

        record = {
            'Session ID':session_id,
            'Mouse ID': session_id[9:],
            'Date': session_id[:8],
            'Phase': phase,
            'Left Reward Prob': params['leftRewardProb'].values,
            'Right Reward Prob': params['rightRewardProb'].values,
            'Block Range Min': params['blockRangeMin'],
            'Block Range Max': params['blockRangeMax'],
            'No. Trials': trials.shape[0],
            'No. Blocks': np.sum(np.diff(trials['Right Reward Prob'].values) != 0),
            'No. Rewards': np.sum(trials['Reward Given']),
            'p(high Port)': np.round(high_p_port.mean(),decimals=2),
            'Decision Window Duration': params['centerPokeRewardWindow'],
            'Min Inter-trial-interval': params['minInterTrialInterval'],
            'Left Solenoid Duration': params['rewardDurationLeft'],
            'Right Solenoid Duration': params['rewardDurationRight']  
                 }
        
        output_df = output_df.append(pd.DataFrame(data=record,columns=names),ignore_index=True)
    except:
        pass

# %%
output_df
# Out:
#      Session ID Mouse ID      Date  Phase  Left Reward Prob  \
# 0   12162016_K1       K1  12162016    2.0               0.3
# 1   11012016_K1       K1  11012016    1.0               1.0
# 2   11022016_K1       K1  11022016    1.0               1.0
# 3   11032016_K1       K1  11032016    1.0               1.0
# 4   11042016_K1       K1  11042016    2.0               0.1
# 5   11042016_K1       K1  11042016    2.0               0.1
# 6   11082016_K1       K1  11082016    1.0               1.0
# 7   11092016_K1       K1  11092016    1.0               1.0
# 8   11102016_K1       K1  11102016    2.0               0.0
# 9   11112016_K1       K1  11112016    2.0               0.0
# 10  11142016_K1       K1  11142016    2.0               0.1
# 11  11152016_K1       K1  11152016    2.0               0.1
# 12  11162016_K1       K1  11162016    2.0               0.1
# 13  11172016_K1       K1  11172016    2.0               0.2
# 14  11182016_K1       K1  11182016    2.0               0.8
# 15  11212016_K1       K1  11212016    2.0               0.2
# 16  11222016_K1       K1  11222016    2.0               0.8
# 17  11292016_K1       K1  11292016    2.0               0.1
# 18  11302016_K1       K1  11302016    2.0               0.8
# 19  12012016_K1       K1  12012016    2.0               0.2
# 20  12022016_K1       K1  12022016    2.0               0.2
# 21  12052016_K1       K1  12052016    2.0               0.2
# 22  12062016_K1       K1  12062016    2.0               0.2
# 23  12072016_K1       K1  12072016    2.0               0.3
# 24  12082016_K1       K1  12082016    2.0               0.3
# 25  12092016_K1       K1  12092016    2.0               0.7
# 26  12122016_K1       K1  12122016    2.0               0.7
# 27  12132016_K1       K1  12132016    2.0               0.7
# 28  12132016_K1       K1  12132016    2.0               0.7
# 29  12162016_K1       K1  12162016    2.0               0.3
#
#     Right Reward Prob  Block Range Min  Block Range Max  No. Trials  \
# 0                 0.7             10.0             40.0       403.0
# 1                 1.0           1000.0           1000.0         8.0
# 2                 1.0           1000.0           1000.0        85.0
# 3                 1.0           1000.0           1000.0       104.0
# 4                 0.9             50.0             50.0        70.0
# 5                 0.9             50.0             50.0        70.0
# 6                 1.0            500.0            500.0       118.0
# 7                 1.0            500.0            500.0       133.0
# 8                 1.0             30.0             30.0       213.0
# 9                 1.0             50.0             50.0       315.0
# 10                0.9             50.0             50.0       415.0
# 11                0.9             50.0             50.0       315.0
# 12                0.9             50.0             50.0       217.0
# 13                0.8             30.0             40.0       198.0
# 14                0.2             20.0             40.0       213.0
# 15                0.8             50.0             50.0       349.0
# 16                0.2             20.0             40.0       281.0
# 17                0.9             50.0             50.0       399.0
# 18                0.2             10.0             40.0       470.0
# 19                0.8             50.0             50.0        91.0
# 20                0.8             10.0             40.0       194.0
# 21                0.8             10.0             40.0       364.0
# 22                0.8             10.0             40.0       521.0
# 23                0.7             10.0             40.0       404.0
# 24                0.7             10.0             40.0       604.0
# 25                0.3             10.0             40.0       586.0
# 26                0.3             10.0             40.0       550.0
# 27                0.3             10.0             40.0       601.0
# 28                0.3             10.0             40.0       601.0
# 29                0.7             10.0             40.0       403.0
#
#     No. Blocks  No. Rewards  p(high Port)  Decision Window Duration  \
# 0         10.0        239.0          0.71                       2.0
# 1          0.0          8.0          0.00                      10.0
# 2          0.0         85.0          0.00                      10.0
# 3          0.0        104.0          0.00                       3.0
# 4          1.0         50.0          0.83                       2.0
# 5          1.0         50.0          0.83                       2.0
# 6          0.0        118.0          0.00                       5.0
# 7          0.0        133.0          0.00                       5.0
# 8          4.0        134.0          0.63                       5.0
# 9          5.0        258.0          0.82                       2.0
# 10         5.0        284.0          0.72                       2.0
# 11         4.0        228.0          0.77                       2.0
# 12         3.0        169.0          0.85                       2.0
# 13         3.0        131.0          0.80                       2.0
# 14         4.0        128.0          0.65                       2.0
# 15         4.0        219.0          0.74                       2.0
# 16         6.0        200.0          0.84                       2.0
# 17         6.0        305.0          0.82                       2.0
# 18        10.0        289.0          0.68                       2.0
# 19         1.0         54.0          0.77                       2.0
# 20         5.0        127.0          0.75                       2.0
# 21         8.0        238.0          0.75                       2.0
# 22        12.0        321.0          0.75                       2.0
# 23         9.0        225.0          0.69                       2.0
# 24        14.0        349.0          0.64                       2.0
# 25        11.0        308.0          0.63                       2.0
# 26        11.0        302.0          0.65                       2.0
# 27        15.0        365.0          0.74                       2.0
# 28        15.0        365.0          0.74                       2.0
# 29        10.0        239.0          0.71                       2.0
#
#     Min Inter-trial-interval  Left Solenoid Duration  Right Solenoid Duration
# 0                        1.0                    35.0                     35.0
# 1                        0.5                    35.0                     35.0
# 2                        0.5                    35.0                     35.0
# 3                        1.0                    35.0                     35.0
# 4                        1.0                    35.0                     35.0
# 5                        1.0                    35.0                     35.0
# 6                        1.0                    60.0                     60.0
# 7                        1.0                    60.0                     60.0
# 8                        1.0                    35.0                     35.0
# 9                        1.0                    35.0                     35.0
# 10                       1.0                    35.0                     35.0
# 11                       1.0                    35.0                     35.0
# 12                       1.0                    35.0                     35.0
# 13                       1.0                    35.0                     35.0
# 14                       1.0                    35.0                     35.0
# 15                       1.0                    35.0                     35.0
# 16                       1.0                    35.0                     35.0
# 17                       1.0                    35.0                     35.0
# 18                       1.0                    35.0                     35.0
# 19                       1.0                    35.0                     35.0
# 20                       1.0                    35.0                     35.0
# 21                       1.0                    35.0                     35.0
# 22                       1.0                    35.0                     35.0
# 23                       1.0                    35.0                     35.0
# 24                       1.0                    35.0                     35.0
# 25                       1.0                    35.0                     35.0
# 26                       1.0                    35.0                     35.0
# 27                       1.0                    35.0                     35.0
# 28                       1.0                    35.0                     35.0
# 29                       1.0                    35.0                     35.0

# %%
import behavior_database

# %%
directory = '/Users/shayneufeld/Dropbox/Shay_BehaviorFiles/BehaviorData_supermice/K1'
test = behavior_database.add_sessions(directory,df)

# %%
directory
# Out:
# '/Users/shayneufeld/Dropbox/Shay_BehaviorFiles/BehaviorData_supermice/K1'

# %%
test
# Out:
#      Session ID Mouse ID      Date  Phase  Left Reward Prob  \
# 0   11012016_K1       K1  11012016    1.0               1.0
# 1   11022016_K1       K1  11022016    1.0               1.0
# 2   11032016_K1       K1  11032016    1.0               1.0
# 3   11042016_K1       K1  11042016    2.0               0.1
# 4   11042016_K1       K1  11042016    2.0               0.1
# 5   11082016_K1       K1  11082016    1.0               1.0
# 6   11092016_K1       K1  11092016    1.0               1.0
# 7   11102016_K1       K1  11102016    2.0               0.0
# 8   11112016_K1       K1  11112016    2.0               0.0
# 9   11142016_K1       K1  11142016    2.0               0.1
# 10  11152016_K1       K1  11152016    2.0               0.1
# 11  11162016_K1       K1  11162016    2.0               0.1
# 12  11172016_K1       K1  11172016    2.0               0.2
# 13  11182016_K1       K1  11182016    2.0               0.8
# 14  11212016_K1       K1  11212016    2.0               0.2
# 15  11222016_K1       K1  11222016    2.0               0.8
# 16  11292016_K1       K1  11292016    2.0               0.1
# 17  11302016_K1       K1  11302016    2.0               0.8
# 18  12012016_K1       K1  12012016    2.0               0.2
# 19  12022016_K1       K1  12022016    2.0               0.2
# 20  12052016_K1       K1  12052016    2.0               0.2
# 21  12062016_K1       K1  12062016    2.0               0.2
# 22  12072016_K1       K1  12072016    2.0               0.3
# 23  12082016_K1       K1  12082016    2.0               0.3
# 24  12092016_K1       K1  12092016    2.0               0.7
# 25  12122016_K1       K1  12122016    2.0               0.7
# 26  12132016_K1       K1  12132016    2.0               0.7
# 27  12132016_K1       K1  12132016    2.0               0.7
# 28  12162016_K1       K1  12162016    2.0               0.3
#
#     Right Reward Prob  Block Range Min  Block Range Max  No. Trials  \
# 0                 1.0           1000.0           1000.0         8.0
# 1                 1.0           1000.0           1000.0        85.0
# 2                 1.0           1000.0           1000.0       104.0
# 3                 0.9             50.0             50.0        70.0
# 4                 0.9             50.0             50.0        70.0
# 5                 1.0            500.0            500.0       118.0
# 6                 1.0            500.0            500.0       133.0
# 7                 1.0             30.0             30.0       213.0
# 8                 1.0             50.0             50.0       315.0
# 9                 0.9             50.0             50.0       415.0
# 10                0.9             50.0             50.0       315.0
# 11                0.9             50.0             50.0       217.0
# 12                0.8             30.0             40.0       198.0
# 13                0.2             20.0             40.0       213.0
# 14                0.8             50.0             50.0       349.0
# 15                0.2             20.0             40.0       281.0
# 16                0.9             50.0             50.0       399.0
# 17                0.2             10.0             40.0       470.0
# 18                0.8             50.0             50.0        91.0
# 19                0.8             10.0             40.0       194.0
# 20                0.8             10.0             40.0       364.0
# 21                0.8             10.0             40.0       521.0
# 22                0.7             10.0             40.0       404.0
# 23                0.7             10.0             40.0       604.0
# 24                0.3             10.0             40.0       586.0
# 25                0.3             10.0             40.0       550.0
# 26                0.3             10.0             40.0       601.0
# 27                0.3             10.0             40.0       601.0
# 28                0.7             10.0             40.0       403.0
#
#     No. Blocks  No. Rewards  p(high Port)  Decision Window Duration  \
# 0          0.0          8.0          0.00                      10.0
# 1          0.0         85.0          0.00                      10.0
# 2          0.0        104.0          0.00                       3.0
# 3          1.0         50.0          0.83                       2.0
# 4          1.0         50.0          0.83                       2.0
# 5          0.0        118.0          0.00                       5.0
# 6          0.0        133.0          0.00                       5.0
# 7          4.0        134.0          0.63                       5.0
# 8          5.0        258.0          0.82                       2.0
# 9          5.0        284.0          0.72                       2.0
# 10         4.0        228.0          0.77                       2.0
# 11         3.0        169.0          0.85                       2.0
# 12         3.0        131.0          0.80                       2.0
# 13         4.0        128.0          0.65                       2.0
# 14         4.0        219.0          0.74                       2.0
# 15         6.0        200.0          0.84                       2.0
# 16         6.0        305.0          0.82                       2.0
# 17        10.0        289.0          0.68                       2.0
# 18         1.0         54.0          0.77                       2.0
# 19         5.0        127.0          0.75                       2.0
# 20         8.0        238.0          0.75                       2.0
# 21        12.0        321.0          0.75                       2.0
# 22         9.0        225.0          0.69                       2.0
# 23        14.0        349.0          0.64                       2.0
# 24        11.0        308.0          0.63                       2.0
# 25        11.0        302.0          0.65                       2.0
# 26        15.0        365.0          0.74                       2.0
# 27        15.0        365.0          0.74                       2.0
# 28        10.0        239.0          0.71                       2.0
#
#     Min Inter-trial-interval  Left Solenoid Duration  Right Solenoid Duration
# 0                        0.5                    35.0                     35.0
# 1                        0.5                    35.0                     35.0
# 2                        1.0                    35.0                     35.0
# 3                        1.0                    35.0                     35.0
# 4                        1.0                    35.0                     35.0
# 5                        1.0                    60.0                     60.0
# 6                        1.0                    60.0                     60.0
# 7                        1.0                    35.0                     35.0
# 8                        1.0                    35.0                     35.0
# 9                        1.0                    35.0                     35.0
# 10                       1.0                    35.0                     35.0
# 11                       1.0                    35.0                     35.0
# 12                       1.0                    35.0                     35.0
# 13                       1.0                    35.0                     35.0
# 14                       1.0                    35.0                     35.0
# 15                       1.0                    35.0                     35.0
# 16                       1.0                    35.0                     35.0
# 17                       1.0                    35.0                     35.0
# 18                       1.0                    35.0                     35.0
# 19                       1.0                    35.0                     35.0
# 20                       1.0                    35.0                     35.0
# 21                       1.0                    35.0                     35.0
# 22                       1.0                    35.0                     35.0
# 23                       1.0                    35.0                     35.0
# 24                       1.0                    35.0                     35.0
# 25                       1.0                    35.0                     35.0
# 26                       1.0                    35.0                     35.0
# 27                       1.0                    35.0                     35.0
# 28                       1.0                    35.0                     35.0
