# %% [markdown]
# # Testing stuff

# %%
import numpy as np

# %% [markdown]
# # Question 1

# %%
F = 0.6
N = 10000.0

upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.019203999583420117

# %%
#decrease F to 0.24
F = 0.24
N = 10000.0
upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.016741658699185091

# %%
#increase F to 0.96
F = 0.96
N = 10000.0
upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.0076815998333681357

# %%
#increase N to 100,000
F = 0.6
N = 100000
upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.0060728378868533106

# %%
#increase N to 1,000,000
F = 0.6
N = 1000000
upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.0019203999583419229

# %%
#increase N to 1,000,000
F = 0.6
N = 100000000
upper = F + 1.96*np.sqrt((1/N)*F*(1-F))
lower = F - 1.96*np.sqrt((1/N)*F*(1-F))
interval = upper - lower
interval
# Out:
# 0.00019203999583417009

# %% [markdown]
# # Question 2

# %%
import itertools
itertools.permutations([1, 2, 3])
all_combos = []
thing = ['apple','apple','banana']

for i in range(1,len(thing)+1):
    for combo in itertools.combinations(thing,i):
        if combo not in all_combos:
            print(combo)
        all_combos.append(combo)
# Out:
# ('apple',)
# ('banana',)
# ('apple', 'apple')
# ('apple', 'banana')
# ('apple', 'apple', 'banana')

# %%
all_combos
# Out:
# [1, 1, 1, 2, 2, 2, 3, 3, 3]

# %%
all_combos
# Out:
# [('apple',), ('apple',), ('banana',)]

# %%
from sklearn.linear_model import LogisticRegression

# %%
x.shape
# Out:
# (7, 2)

# %%
y.shape
# Out:
# (7,)

# %%
x = np.array([[1,0.4],
     [1,0.5],
     [1,0.6],
     [1,0.7],
     [1,0.8],
     [1,0.9],
     [1,1.0]])
y = np.arange(0.4,1.1,0.1)
x_test = [5,6,7,8]

logreg = LogisticRegression()
logreg.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-53cf3c696f6e> in <module>()
#      10
#      11 logreg = LogisticRegression()
# ---> 12 logreg.fit(x,y)
#
# /Users/shayneufeld/anaconda/envs/cagrin/lib/python3.5/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
#    1173                          order="C")
# -> 1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#    1176         n_samples, n_features = X.shape
#
# /Users/shayneufeld/anaconda/envs/cagrin/lib/python3.5/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171             'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'
